# %% [markdown]
# # **Helicobacter pylori CNN classifier**

# %% [markdown]
# Import necessary libraries

# %%
# Load libraries

import torch
import numpy as np
import torch
import glob # for listing files in the directory, asemejan un patrón especificado de acuerdo con las reglas de coincidencia de Unix
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.svm import SVC
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from torch.optim import Adam
from torch.autograd import Variable
from torch.utils.data import random_split
from torchvision import transforms
from multiprocessing import Pool
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import random
import cv2
import pathlib
import os

# %%
torch.cuda.empty_cache()

# %% [markdown]
# Cuda available

# %%
# Check for device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device) # If gpu is available, cuda will be printed
# Out:
# cuda

# %% [markdown]
# **Dataloader process**

# %%
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torchvision import transforms
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import os

# Define a custom dataset class for the Helicobacter pylori classifier
class HPylorisDatasetClassifier(Dataset):
    def __init__(self, data_folder, annotations, specifyPaths=None, infected=0, returnLabels=True, transform=None):
        """
        Inputs: 
            DATA_FOLDER: folder that contains all folders with the annotated images.
            ANNOTATIONS: csv file that labels the input images
            SPECIFYPATHS: txt file with the paths of the images to retrieve with its corresponding label
            INFECTED: add infected (1), non-infected (-1) or all images (0) to dataset
            RETURNLABELS: return image labels (1) or not (0)
            TRANSFORM: apply any kind of torchvision transforms to the images        
        """
        self.data_folder = data_folder
        self.annotations = annotations
        self.infected = infected
        self.returnLabels = returnLabels
        self.transform = transform
        # Obtain all images from the annotations file and store them in a list
        self.images = self.obtain_all_images(self.annotations, 
                                             self.data_folder,
                                             self.infected,
                                             specifyPaths)
        
    def obtain_all_images(self, annotations, data_folder, infected, specifyPatients):
        output = []        
        if annotations != None:
            labels = pd.read_csv(annotations)
        negative_samples, positive_samples = 0, 0
        
        if specifyPatients == None:
            # Iterate over all rows in the annotations file
            for _, row in labels.iterrows():
                image_names = row['ID'].split('.')
                presence = row['Presence']
                # If we want all images or only infected/non-infected images, add the image to the list
                if infected == 0 and presence != 0:
                    image_path = os.path.join(data_folder,image_names[0], image_names[1]+'.png')
                    if os.path.exists(image_path):
                        if presence == -1:
                            if negative_samples < positive_samples:
                                output.append((image_path, 0))
                                negative_samples += 1
                        else:
                            output.append((image_path, presence))
                            positive_samples += 1       
            print(output)
            return output
        else:
            with open(specifyPatients, 'r') as file:
                specifyPatients = [tuple(line[:-1].split(',')) for line in file.readlines()]
            output = []
            for instance in specifyPatients:
                output.append((instance[0], int(instance[1])))
            print(output)
            return output

    def get_path_label(self, idx):
        # Return the image name and label at the specified index
        img_path, label = self.images[idx]
        return img_path, label

    def __len__(self):
        # Return the length of the list of images
        return len(self.images)

    def __getitem__(self, idx):
        # Get the image name and label at the specified index
        img_name, label = self.images[idx]
        try:
            # Open the image and convert it to RGB
            image = Image.open(img_name).convert('RGB')
            # Apply any specified transforms to the image
            if self.transform:
                image = self.transform(image)
            else:
                image = transforms.ToTensor(image)
            # If we want to return the labels, return the image and label
            if self.returnLabels:
                return image, label
            # Otherwise, return just the image
            else:
                return image
        except Exception as e:
            # If there was an error loading the image, print an error message and return None
            print(f"Error loading image '{img_name}': {str(e)}")
            return None

# %%
# Define the paths to the annotated labels and image folders
annotated_labels_path = '/fhome/mapsiv/QuironHelico/AnnotatedPatches/window_metadata.csv'
annotated_image_folders_path = '/fhome/mapsiv/QuironHelico/AnnotatedPatches/'

# Define data augmentation transforms
myTransforms = transforms.Compose([ transforms.Resize((224,224)), # Resize the image to 224x224
                                    transforms.RandomHorizontalFlip(),  # Randomly flip the image horizontally
                                    transforms.RandomVerticalFlip(),    # Randomly flip the image vertically
                                    transforms.RandomRotation(10),   # Randomly rotate the image by 10 degrees
                                    transforms.ToTensor(),       # Convert the image to a tensor
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # Normalize the image
])

SpecifyPatientsPath = '/fhome/gia01/vl_project2/randomDatasetCNN.txt'

# Create three datasets: one with all images, one with non-infected images, and one with infected images
CLF_fullDataset = HPylorisDatasetClassifier(data_folder = annotated_image_folders_path, 
                                            annotations = None,
                                            specifyPaths = SpecifyPatientsPath, 
                                            transform = myTransforms)

# Define the ratios for train, validation, and test datasets
train_ratio = 0.70
val_ratio = 0.20
test_ratio = 0.10

# Calculate the sizes of the train, validation, and test datasets
train_size = int(train_ratio * len(CLF_fullDataset))
val_size = int(val_ratio * len(CLF_fullDataset))
test_size = len(CLF_fullDataset) - train_size - val_size

# Split the full dataset into train, validation, and test datasets
train_dataset, val_dataset, test_dataset = random_split(CLF_fullDataset, [train_size, val_size, test_size])

# Create data loaders for the train, validation and test datasets

CLF_train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
CLF_val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)
CLF_test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)
# Out:
# [('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-70_0/00154.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-219_0/00032.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-163_0/00491.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-114_0/00112.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-304_0/00381.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-275_0/00144.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-277_0/00601.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-103_0/02245.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-170_0/01015.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-138_0/00351.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-304_0/01100.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-102_0/01468.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-138_0/00879.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-302_0/00168.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-313_0/01552.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-46_0/01338.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-249_0/00183.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-264_0/01511.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-304_0/01044.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-155_0/02125.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-101_0/00201.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-299_0/00773.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-138_0/00699.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-84_0/00582.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-126_0/01734.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-138_0/01365.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-138_0/01649.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-156_0/00139.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-163_0/00657.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-126_0/01535.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-170_0/00949.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-74_0/00890.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-155_0/02989.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-126_0/00667.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-278_0/00022.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-155_0/00588.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-155_0/03707.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-163_0/00387.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-38_0/01284.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-37_0/00272.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-155_0/02987.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-116_0/00256.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-45_0/00741.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-302_0/00846.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-155_0/01760.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-312_0/01780.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-37_0/00045.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-126_0/01483.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-163_0/00298.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-45_0/01027.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-138_0/00892.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-123_0/00696.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-84_0/00099.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-138_0/01500.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22-240_0/00500.png', 1), ('/fhome/mapsiv/QuironHelico/AnnotatedPatches/B22 ...

# %% [markdown]
# Define the classes

# %% [markdown]
# # CNN Architecture

# %%
# Convoloitional neural network
class ConvNet(nn.Module):

    def __init__(self, num_classes = 2):
        super(ConvNet, self).__init__()

        """ 

        Output size after convolutional filter:
        ((input_size - kernel + 2 * padding)/ stride) + 1
        
        """

        # Input shape = (3, 224, 224)
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
        # Shape = (16, 224, 224) -- Same shape as input, but more channels
        # Add batch normalization
        self.bn1 = nn.BatchNorm2d(num_features=16) # Shape = (16, 224, 224)
        # Add activation function
        self.relu1 = nn.ReLU() # Shape = (16, 224, 224)
        # Max pool 1, reuduce the image size be factor 2
        self.pool1 = nn.MaxPool2d(kernel_size=2) # Shape = (16, 112, 112)

        # Add second convolutional layer
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        # Shape = (32, 112, 112)
        # Add activation function
        self.relu2 = nn.ReLU() # Shape = (32, 112, 112)

        # Add third convolutional layer
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1) # Shape = (64, 112, 112)
        # Add batch normalization
        self.bn3 = nn.BatchNorm2d(num_features=64) # Shape = (64, 112, 112)
        # Add activation function
        self.relu3 = nn.ReLU() # Shape = (64, 112, 112)

        # Linear layer (64 * 112 * 112 -> 2)
        self.fc = nn.Linear(in_features=64 * 112 * 112, out_features=num_classes)

    # Feed forward function
    def forward(self, input):
        # Convolutional layer
        output = self.conv1(input)
        # Batch normalization
        output = self.bn1(output)
        # Activation function
        output = self.relu1(output)
        # Max pool
        output = self.pool1(output)

        # Convolutional layer
        output = self.conv2(output)
        # Activation function
        output = self.relu2(output)

        # Convolutional layer
        output = self.conv3(output)
        # Batch normalization
        output = self.bn3(output)
        # Activation function
        output = self.relu3(output)

        # Above output will be in matrix form with shape (64, 112, 112)

        # Flatten
        output = output.view(-1, 64 * 112 * 112)

        # Linear layer (output -> 2)
        output = self.fc(output)

        return output

# %% [markdown]
# Load model

# %%
# Create model
modelCNN = ConvNet(num_classes = 2)

# Pass model to GPU
modelCNN.to(device)
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (fc): Linear(in_features=802816, out_features=2, bias=True)
# )

# %% [markdown]
# Optimizer and loss function

# %%
# Optimizer
optimizer = torch.optim.Adam(modelCNN.parameters(), lr=0.001, weight_decay=0.0001)

# Loss function
loss_function = nn.CrossEntropyLoss()

# %%
# Number of epochs
num_epoch = 100

# %% [markdown]
# # Training

# %%
from cProfile import label
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np

# Import the necessary modules

# FILEPATH: /fhome/gia01/vl_project2/src/CNN_classifier.ipynb
# Model training
best_accuracy = 0.0

epochs_list = list() # List of epochs

Train_loss_list = list() # Training loss list
Train_accuracy_list = list() # Accuracy list - indicates how well the model has learned to classify the training data

Val_accuracy_list = list() # Accuracy list - indicated how well the model generalizes to new, unseen data
Val_loss_list = list() # Validation loss list 

Train_true_labels = list() # label
Val_true_labels = list() # label

Train_pred_labels = list() # prediction
Val_pred_labels = list() # prediction

for epoch in range (num_epoch): # Training loop

   # Display number of actual epoch
   print("------------------------------------------------------------------------\n")
   print(f'Epoch: {epoch+1}/{num_epoch}\n')

   # Set the model to training mode, training dataset
   modelCNN.train()

   epochs_list.append(epoch + 1) # Append epoch to list

   train_accuracy = 0.0 # Accuracy of the model
   train_loss = 0.0 

   # Iterate over the training dataset
   for i, (images, labels) in enumerate(CLF_train_loader):

      # Pass images and labels to GPU
      images = images.to(device)
      labels = labels.to(device)

      optimizer.zero_grad() # Clear optimizer
      outputs = modelCNN(images) # Forward pass

      loss = loss_function(outputs, labels) # Calculate loss

      loss.backward() # Backpropagation of the loss
      optimizer.step() # Update weights of the network

      train_loss += loss.cpu().data*images.size(0) # Update train loss
      _, prediction = torch.max(outputs.data, 1)

      train_accuracy += int(torch.sum(prediction == labels.data)) # Update train accuracy

      # Calculate confusion matrix

   train_accuracy = train_accuracy / train_size # Get the accuracy
   Train_accuracy_list.append(train_accuracy) # Append train accuracy to list

   train_loss = train_loss / train_size # Get the loss
   Train_loss_list.append(train_loss) # Append loss to list

   val_accuracy = 0.0 # Accuracy of the model
   val_loss = 0.0 # Loss of the model

   # Set the model to evaluation mode, validation dataset
   modelCNN.eval()

   # Iterate over the validation dataset
   for i, (images, labels) in enumerate(CLF_val_loader):

      # Pass images and labels to GPU
      images = images.to(device)
      labels = labels.to(device)

      outputs = modelCNN(images) # Forward pass
      loss = loss_function(outputs, labels) # Calculate loss

      val_loss += loss.cpu().data*images.size(0) # Update validation loss

      _, prediction = torch.max(outputs.data, 1)
      val_accuracy += int(torch.sum(prediction == labels.data)) # Update validation accuracy

      # Calculate confusion matrix

   val_accuracy = val_accuracy / val_size # Get the accuracy
   Val_accuracy_list.append(val_accuracy) # Append validation accuracy to list

   val_loss = val_loss / val_size # Get the loss
   Val_loss_list.append(val_loss) # Append loss to list

   print(f'Epoch: {epoch + 1}, Train Loss: {train_loss}, Train Accuracy: {train_accuracy}, Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}\n')

   # Save the best model
   if (val_accuracy > best_accuracy): 

      # Save model
      torch.save(modelCNN.state_dict(), 'best_checkpoint.model')
      best_accuracy = val_accuracy # Update best accuracy
# Out:
# ------------------------------------------------------------------------
#
# Epoch: 1/100
# Epoch: 1, Train Loss: 44.58322525024414, Train Accuracy: 0.5398230088495575, Validation Loss: 21.990890502929688, Validation Accuracy: 0.40625
#
# ------------------------------------------------------------------------
#
# Epoch: 2/100
#
# Epoch: 2, Train Loss: 22.93974494934082, Train Accuracy: 0.6194690265486725, Validation Loss: 6.584232330322266, Validation Accuracy: 0.40625
#
# ------------------------------------------------------------------------
#
# Epoch: 3/100
#
# Epoch: 3, Train Loss: 18.554912567138672, Train Accuracy: 0.5486725663716814, Validation Loss: 1.2227061986923218, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 4/100
#
# Epoch: 4, Train Loss: 14.527664184570312, Train Accuracy: 0.6017699115044248, Validation Loss: 0.8993991613388062, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 5/100
#
# Epoch: 5, Train Loss: 16.866621017456055, Train Accuracy: 0.6017699115044248, Validation Loss: 17.348840713500977, Validation Accuracy: 0.40625
#
# ------------------------------------------------------------------------
#
# Epoch: 6/100
#
# Epoch: 6, Train Loss: 10.705222129821777, Train Accuracy: 0.6460176991150443, Validation Loss: 12.850358963012695, Validation Accuracy: 0.5
#
# ------------------------------------------------------------------------
#
# Epoch: 7/100
#
# Epoch: 7, Train Loss: 5.339821815490723, Train Accuracy: 0.7345132743362832, Validation Loss: 6.776397228240967, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 8/100
#
# Epoch: 8, Train Loss: 2.883639335632324, Train Accuracy: 0.7522123893805309, Validation Loss: 6.659381866455078, Validation Accuracy: 0.46875
#
# ------------------------------------------------------------------------
#
# Epoch: 9/100
#
# Epoch: 9, Train Loss: 3.7025814056396484, Train Accuracy: 0.7079646017699115, Validation Loss: 9.568009376525879, Validation Accuracy: 0.5
#
# ------------------------------------------------------------------------
#
# Epoch: 10/100
#
# Epoch: 10, Train Loss: 7.822279453277588, Train Accuracy: 0.6106194690265486, Validation Loss: 24.573450088500977, Validation Accuracy: 0.4375
#
# ------------------------------------------------------------------------
#
# Epoch: 11/100
#
# Epoch: 11, Train Loss: 9.152482986450195, Train Accuracy: 0.7168141592920354, Validation Loss: 7.1728997230529785, Validation Accuracy: 0.5
#
# ------------------------------------------------------------------------
#
# Epoch: 12/100
#
# Epoch: 12, Train Loss: 4.870088577270508, Train Accuracy: 0.7168141592920354, Validation Loss: 8.021238327026367, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 13/100
#
# Epoch: 13, Train Loss: 4.967870235443115, Train Accuracy: 0.6814159292035398, Validation Loss: 5.590627193450928, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 14/100
#
# Epoch: 14, Train Loss: 4.130843639373779, Train Accuracy: 0.7168141592920354, Validation Loss: 6.528480052947998, Validation Accuracy: 0.5
#
# ------------------------------------------------------------------------
#
# Epoch: 15/100
#
# Epoch: 15, Train Loss: 5.052347183227539, Train Accuracy: 0.672566371681416, Validation Loss: 9.939592361450195, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 16/100
#
# Epoch: 16, Train Loss: 5.301842212677002, Train Accuracy: 0.7079646017699115, Validation Loss: 8.997442245483398, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 17/100
#
# Epoch: 17, Train Loss: 5.366471290588379, Train Accuracy: 0.6991150442477876, Validation Loss: 6.988640785217285, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 18/100
#
# Epoch: 18, Train Loss: 2.4538345336914062, Train Accuracy: 0.831858407079646, Validation Loss: 9.966469764709473, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 19/100
#
# Epoch: 19, Train Loss: 2.958829402923584, Train Accuracy: 0.8053097345132744, Validation Loss: 7.574089527130127, Validation Accuracy: 0.46875
#
# ------------------------------------------------------------------------
#
# Epoch: 20/100
#
# Epoch: 20, Train Loss: 4.404201030731201, Train Accuracy: 0.7522123893805309, Validation Loss: 6.834931373596191, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 21/100
#
# Epoch: 21, Train Loss: 6.10812520980835, Train Accuracy: 0.7522123893805309, Validation Loss: 24.003658294677734, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 22/100
#
# Epoch: 22, Train Loss: 4.06464147567749, Train Accuracy: 0.7876106194690266, Validation Loss: 7.318864822387695, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 23/100
#
# Epoch: 23, Train Loss: 4.272402763366699, Train Accuracy: 0.8141592920353983, Validation Loss: 4.3989763259887695, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 24/100
#
# Epoch: 24, Train Loss: 2.161200523376465, Train Accuracy: 0.8141592920353983, Validation Loss: 13.043829917907715, Validation Accuracy: 0.5
#
# ------------------------------------------------------------------------
#
# Epoch: 25/100
#
# Epoch: 25, Train Loss: 2.1752960681915283, Train Accuracy: 0.8053097345132744, Validation Loss: 20.538522720336914, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 26/100
#
# Epoch: 26, Train Loss: 2.081291437149048, Train Accuracy: 0.8230088495575221, Validation Loss: 12.04370403289795, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 27/100
#
# Epoch: 27, Train Loss: 2.6704814434051514, Train Accuracy: 0.8053097345132744, Validation Loss: 10.655824661254883, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 28/100
#
# Epoch: 28, Train Loss: 5.85162353515625, Train Accuracy: 0.7168141592920354, Validation Loss: 10.532421112060547, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 29/100
#
# Epoch: 29, Train Loss: 2.794764757156372, Train Accuracy: 0.8141592920353983, Validation Loss: 17.986984252929688, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 30/100
#
# Epoch: 30, Train Loss: 8.55416488647461, Train Accuracy: 0.6814159292035398, Validation Loss: 19.554738998413086, Validation Accuracy: 0.5
#
# ------------------------------------------------------------------------
#
# Epoch: 31/100
#
# Epoch: 31, Train Loss: 2.4032626152038574, Train Accuracy: 0.8495575221238938, Validation Loss: 13.092556953430176, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 32/100
#
# Epoch: 32, Train Loss: 2.995844841003418, Train Accuracy: 0.8672566371681416, Validation Loss: 7.337843894958496, Validation Accuracy: 0.53125
#
# ------------------------------------------------------------------------
#
# Epoch: 33/100
#
# Epoch: 33, Train Loss: 2.192936658859253, Train Accuracy: 0.8141592920353983, Validation Loss: 13.958139419555664, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 34/100
#
# Epoch: 34, Train Loss: 3.6163580417633057, Train Accuracy: 0.8141592920353983, Validation Loss: 20.802940368652344, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 35/100
#
# Epoch: 35, Train Loss: 1.0384752750396729, Train Accuracy: 0.8849557522123894, Validation Loss: 14.605725288391113, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 36/100
#
# Epoch: 36, Train Loss: 2.2569613456726074, Train Accuracy: 0.8584070796460177, Validation Loss: 9.516922950744629, Validation Accuracy: 0.5
#
# ------------------------------------------------------------------------
#
# Epoch: 37/100
#
# Epoch: 37, Train Loss: 0.950749397277832, Train Accuracy: 0.9203539823008849, Validation Loss: 7.599771499633789, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 38/100
#
# Epoch: 38, Train Loss: 2.44392466545105, Train Accuracy: 0.8407079646017699, Validation Loss: 15.258522033691406, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 39/100
#
# Epoch: 39, Train Loss: 1.8057562112808228, Train Accuracy: 0.8849557522123894, Validation Loss: 8.811548233032227, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 40/100
#
# Epoch: 40, Train Loss: 4.879060745239258, Train Accuracy: 0.7964601769911505, Validation Loss: 3.561403512954712, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 41/100
#
# Epoch: 41, Train Loss: 1.7578452825546265, Train Accuracy: 0.8584070796460177, Validation Loss: 5.407016277313232, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 42/100
#
# Epoch: 42, Train Loss: 0.7560102939605713, Train Accuracy: 0.8761061946902655, Validation Loss: 18.60297966003418, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 43/100
#
# Epoch: 43, Train Loss: 3.8230395317077637, Train Accuracy: 0.8230088495575221, Validation Loss: 11.923739433288574, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 44/100
#
# Epoch: 44, Train Loss: 5.427119731903076, Train Accuracy: 0.7699115044247787, Validation Loss: 164.28749084472656, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 45/100
#
# Epoch: 45, Train Loss: 4.836483478546143, Train Accuracy: 0.8230088495575221, Validation Loss: 57.435699462890625, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 46/100
#
# Epoch: 46, Train Loss: 6.070817470550537, Train Accuracy: 0.7964601769911505, Validation Loss: 13.972624778747559, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 47/100
#
# Epoch: 47, Train Loss: 7.181398868560791, Train Accuracy: 0.8495575221238938, Validation Loss: 9.842693328857422, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 48/100
#
# Epoch: 48, Train Loss: 4.388038635253906, Train Accuracy: 0.831858407079646, Validation Loss: 36.19416046142578, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 49/100
#
# Epoch: 49, Train Loss: 2.156639575958252, Train Accuracy: 0.8672566371681416, Validation Loss: 100.80896759033203, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 50/100
#
# Epoch: 50, Train Loss: 3.403550863265991, Train Accuracy: 0.8230088495575221, Validation Loss: 20.66465187072754, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 51/100
#
# Epoch: 51, Train Loss: 11.89454174041748, Train Accuracy: 0.7345132743362832, Validation Loss: 22.930618286132812, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 52/100
#
# Epoch: 52, Train Loss: 7.275412559509277, Train Accuracy: 0.8053097345132744, Validation Loss: 10.182960510253906, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 53/100
#
# Epoch: 53, Train Loss: 5.162348747253418, Train Accuracy: 0.8672566371681416, Validation Loss: 50.634769439697266, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 54/100
#
# Epoch: 54, Train Loss: 6.107410430908203, Train Accuracy: 0.8230088495575221, Validation Loss: 17.759124755859375, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 55/100
#
# Epoch: 55, Train Loss: 2.7941250801086426, Train Accuracy: 0.8584070796460177, Validation Loss: 24.380226135253906, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 56/100
#
# Epoch: 56, Train Loss: 5.480624675750732, Train Accuracy: 0.7964601769911505, Validation Loss: 30.372142791748047, Validation Accuracy: 0.53125
#
# ------------------------------------------------------------------------
#
# Epoch: 57/100
#
# Epoch: 57, Train Loss: 7.962454319000244, Train Accuracy: 0.7522123893805309, Validation Loss: 13.566963195800781, Validation Accuracy: 0.53125
#
# ------------------------------------------------------------------------
#
# Epoch: 58/100
#
# Epoch: 58, Train Loss: 3.5475573539733887, Train Accuracy: 0.831858407079646, Validation Loss: 16.3898868560791, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 59/100
#
# Epoch: 59, Train Loss: 2.7252447605133057, Train Accuracy: 0.8584070796460177, Validation Loss: 7.558964729309082, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 60/100
#
# Epoch: 60, Train Loss: 2.0559520721435547, Train Accuracy: 0.8584070796460177, Validation Loss: 2.223961591720581, Validation Accuracy: 0.75
#
# ------------------------------------------------------------------------
#
# Epoch: 61/100
#
# Epoch: 61, Train Loss: 2.090522050857544, Train Accuracy: 0.8761061946902655, Validation Loss: 4.002755165100098, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 62/100
#
# Epoch: 62, Train Loss: 0.6505919694900513, Train Accuracy: 0.9646017699115044, Validation Loss: 4.657258033752441, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 63/100
#
# Epoch: 63, Train Loss: 1.1939563751220703, Train Accuracy: 0.9203539823008849, Validation Loss: 3.7877767086029053, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 64/100
#
# Epoch: 64, Train Loss: 0.9698581099510193, Train Accuracy: 0.9292035398230089, Validation Loss: 5.2449235916137695, Validation Accuracy: 0.75
#
# ------------------------------------------------------------------------
#
# Epoch: 65/100
#
# Epoch: 65, Train Loss: 0.45011547207832336, Train Accuracy: 0.9646017699115044, Validation Loss: 3.9377660751342773, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 66/100
#
# Epoch: 66, Train Loss: 0.4341362416744232, Train Accuracy: 0.9646017699115044, Validation Loss: 4.678461074829102, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 67/100
#
# Epoch: 67, Train Loss: 0.2985471189022064, Train Accuracy: 0.9557522123893806, Validation Loss: 7.714914321899414, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 68/100
#
# Epoch: 68, Train Loss: 0.574463963508606, Train Accuracy: 0.9292035398230089, Validation Loss: 3.4418134689331055, Validation Accuracy: 0.8125
#
# ------------------------------------------------------------------------
#
# Epoch: 69/100
#
# Epoch: 69, Train Loss: 1.3557370901107788, Train Accuracy: 0.8584070796460177, Validation Loss: 10.804821014404297, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 70/100
#
# Epoch: 70, Train Loss: 1.190327763557434, Train Accuracy: 0.9203539823008849, Validation Loss: 17.871227264404297, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 71/100
#
# Epoch: 71, Train Loss: 0.8532017469406128, Train Accuracy: 0.9380530973451328, Validation Loss: 4.99934720993042, Validation Accuracy: 0.75
#
# ------------------------------------------------------------------------
#
# Epoch: 72/100
#
# Epoch: 72, Train Loss: 1.0680662393569946, Train Accuracy: 0.9026548672566371, Validation Loss: 2.6104681491851807, Validation Accuracy: 0.75
#
# ------------------------------------------------------------------------
#
# Epoch: 73/100
#
# Epoch: 73, Train Loss: 0.39080455899238586, Train Accuracy: 0.9557522123893806, Validation Loss: 11.256904602050781, Validation Accuracy: 0.71875
#
# ------------------------------------------------------------------------
#
# Epoch: 74/100
#
# Epoch: 74, Train Loss: 1.071704626083374, Train Accuracy: 0.9203539823008849, Validation Loss: 9.966519355773926, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 75/100
#
# Epoch: 75, Train Loss: 0.5646098852157593, Train Accuracy: 0.8938053097345132, Validation Loss: 13.032915115356445, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 76/100
#
# Epoch: 76, Train Loss: 0.41484197974205017, Train Accuracy: 0.9734513274336283, Validation Loss: 12.014734268188477, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 77/100
#
# Epoch: 77, Train Loss: 0.7727388143539429, Train Accuracy: 0.9203539823008849, Validation Loss: 10.300990104675293, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 78/100
#
# Epoch: 78, Train Loss: 0.05013894662261009, Train Accuracy: 0.9734513274336283, Validation Loss: 4.687337875366211, Validation Accuracy: 0.59375
#
# ------------------------------------------------------------------------
#
# Epoch: 79/100
#
# Epoch: 79, Train Loss: 0.026530710980296135, Train Accuracy: 0.9911504424778761, Validation Loss: 5.027259826660156, Validation Accuracy: 0.5625
#
# ------------------------------------------------------------------------
#
# Epoch: 80/100
#
# Epoch: 80, Train Loss: 0.27947545051574707, Train Accuracy: 0.9734513274336283, Validation Loss: 4.470022678375244, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 81/100
#
# Epoch: 81, Train Loss: 0.35736024379730225, Train Accuracy: 0.9911504424778761, Validation Loss: 4.47601318359375, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 82/100
#
# Epoch: 82, Train Loss: 0.31860336661338806, Train Accuracy: 0.9292035398230089, Validation Loss: 7.166031360626221, Validation Accuracy: 0.71875
#
# ------------------------------------------------------------------------
#
# Epoch: 83/100
#
# Epoch: 83, Train Loss: 0.6422503590583801, Train Accuracy: 0.9557522123893806, Validation Loss: 8.075565338134766, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 84/100
#
# Epoch: 84, Train Loss: 0.49705612659454346, Train Accuracy: 0.9469026548672567, Validation Loss: 2.8323190212249756, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 85/100
#
# Epoch: 85, Train Loss: 0.3370401859283447, Train Accuracy: 0.9557522123893806, Validation Loss: 4.450106143951416, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 86/100
#
# Epoch: 86, Train Loss: 0.10356572270393372, Train Accuracy: 0.9911504424778761, Validation Loss: 9.099003791809082, Validation Accuracy: 0.71875
#
# ------------------------------------------------------------------------
#
# Epoch: 87/100
#
# Epoch: 87, Train Loss: 0.7365307211875916, Train Accuracy: 0.9380530973451328, Validation Loss: 4.390912055969238, Validation Accuracy: 0.8125
#
# ------------------------------------------------------------------------
#
# Epoch: 88/100
#
# Epoch: 88, Train Loss: 0.15933546423912048, Train Accuracy: 0.9734513274336283, Validation Loss: 2.9144864082336426, Validation Accuracy: 0.75
#
# ------------------------------------------------------------------------
#
# Epoch: 89/100
#
# Epoch: 89, Train Loss: 0.4511101543903351, Train Accuracy: 0.9469026548672567, Validation Loss: 3.4232122898101807, Validation Accuracy: 0.71875
#
# ------------------------------------------------------------------------
#
# Epoch: 90/100
#
# Epoch: 90, Train Loss: 0.15487034618854523, Train Accuracy: 0.9646017699115044, Validation Loss: 4.409567832946777, Validation Accuracy: 0.75
#
# ------------------------------------------------------------------------
#
# Epoch: 91/100
#
# Epoch: 91, Train Loss: 0.18763771653175354, Train Accuracy: 0.9734513274336283, Validation Loss: 5.803147792816162, Validation Accuracy: 0.71875
#
# ------------------------------------------------------------------------
#
# Epoch: 92/100
#
# Epoch: 92, Train Loss: 0.0013432333944365382, Train Accuracy: 1.0, Validation Loss: 4.735974311828613, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 93/100
#
# Epoch: 93, Train Loss: 0.25613129138946533, Train Accuracy: 0.9557522123893806, Validation Loss: 4.203090667724609, Validation Accuracy: 0.8125
#
# ------------------------------------------------------------------------
#
# Epoch: 94/100
#
# Epoch: 94, Train Loss: 0.21128256618976593, Train Accuracy: 0.9823008849557522, Validation Loss: 9.10085678100586, Validation Accuracy: 0.65625
#
# ------------------------------------------------------------------------
#
# Epoch: 95/100
#
# Epoch: 95, Train Loss: 0.03515488654375076, Train Accuracy: 0.9823008849557522, Validation Loss: 5.3327717781066895, Validation Accuracy: 0.75
#
# ------------------------------------------------------------------------
#
# Epoch: 96/100
#
# Epoch: 96, Train Loss: 0.0005171851953491569, Train Accuracy: 1.0, Validation Loss: 4.80955696105957, Validation Accuracy: 0.78125
#
# ------------------------------------------------------------------------
#
# Epoch: 97/100
#
# Epoch: 97, Train Loss: 1.123287320137024, Train Accuracy: 0.9646017699115044, Validation Loss: 8.292926788330078, Validation Accuracy: 0.71875
#
# ------------------------------------------------------------------------
#
# Epoch: 98/100
#
# Epoch: 98, Train Loss: 0.1271904706954956, Train Accuracy: 0.9823008849557522, Validation Loss: 13.008828163146973, Validation Accuracy: 0.625
#
# ------------------------------------------------------------------------
#
# Epoch: 99/100
#
# Epoch: 99, Train Loss: 0.06033448874950409, Train Accuracy: 0.9911504424778761, Validation Loss: 10.92950439453125, Validation Accuracy: 0.6875
#
# ------------------------------------------------------------------------
#
# Epoch: 100/100
#
# Epoch: 100, Train Loss: 0.04965415969491005, Train Accuracy: 0.9911504424778761, Validation Loss: 4.121384620666504, Validation Accuracy: 0.75

# %%
# Training loss plot

plt.rcParams['figure.figsize'] = [12, 7] # Set the size of the plot

plt.title('Losses')
plt.plot(epochs_list, Train_loss_list, "-b", label = 'Training Loss')
plt.plot(epochs_list, Val_loss_list, "-g", label = 'Validation Loss')
plt.xlabel("n epoch")
plt.legend(loc = 'upper left')
plt.show()

# %%
# Accuracy plot 
plt.plot(epochs_list, Train_accuracy_list, "-b", label = 'Training accuracy')
plt.plot(epochs_list, Val_accuracy_list, "-g", label = 'Validation accuracy')
plt.xlabel("n epoch")
plt.legend(loc = 'upper left')
plt.title('Accuracy')
plt.show()

print("Average training accuracy:", (sum(Train_accuracy_list) / len(Train_accuracy_list))) # Training accuracy
print("Average validation accuracy:", (sum(Val_accuracy_list) / len(Val_accuracy_list))) # Validation accuracy
# Out:
# Average training accuracy: 0.8465486725663718
# Average validation accuracy: 0.6234375

# %% [markdown]
# # **Helicobacter pylori CNN classifier with K fold cross validation**

# %% [markdown]
# K fold cross validation

# %%
num_splits = 5  # Number of folds for cross-validation
kfold = KFold(n_splits=num_splits, shuffle=True, random_state=42) # Define K fold

# %% [markdown]
# Define the train function in order to perform K fold cross validation

# %%
from sklearn.metrics import classification_report

# Define the train function
def train(model, CLF_train_loader, CLF_val_loader, num_epoch, loss_function, optimizer, device):

    # Model training
    best_accuracy = 0.0
    patience = 5 # Number of epoch to wait for improvement
    stop_early = 0 # Counter for early stopping

    epochs_list = list() # List of epochs

    Train_loss_list = list() # Training loss list
    Train_accuracy_list = list() # Accuracy list - indicates how well the model has learned to classify the training data

    Val_accuracy_list = list() # Accuracy list - indicated how well the model generalizes to new, unseen data
    Val_loss_list = list() # Validation loss list 

    for epoch in range (num_epoch): # Training loop

        # Display number of actual epoch
        print("------------------------------------------------------------------------\n")
        print(f'Epoch: {epoch+1}/{num_epoch}\n')

        # Set the model to training mode, training dataset
        modelCNN.train()

        epochs_list.append(epoch + 1) # Append epoch to list

        train_accuracy = 0.0 # Accuracy of the model
        train_loss = 0.0 

        # Iterate over the training dataset
        for i, (images, labels) in enumerate(CLF_train_loader):

            # Pass images and labels to GPU
            if torch.cuda.is_available():
                images = Variable(images).cuda()
                labels = Variable(labels).cuda()

            optimizer.zero_grad() # Clear optimizer
            outputs = modelCNN(images) # Forward pass

            loss = loss_function(outputs, labels) # Calculate loss

            loss.backward() # Backpropagation of the loss
            optimizer.step() # Update weights of the network

            train_loss += loss.cpu().data*images.size(0) # Update train loss
            _, prediction = torch.max(outputs.data, 1)

            train_accuracy += int(torch.sum(prediction == labels.data)) # Update train accuracy

        train_accuracy = train_accuracy / train_size # Get the accuracy
        Train_accuracy_list.append(train_accuracy) # Append train accuracy to list

        train_loss = train_loss / train_size # Get the loss
        Train_loss_list.append(train_loss) # Append loss to list

        val_accuracy = 0.0 # Accuracy of the model

        # Set the model to evaluation mode, validation dataset
        modelCNN.eval()

        val_loss = 0.0 # Loss of the model

        # Iterate over the validation dataset
        for i, (images, labels) in enumerate(CLF_val_loader):

            # Pass images and labels to GPU
            if torch.cuda.is_available():
                images = Variable(images).cuda()
                labels = Variable(labels).cuda()

            outputs = modelCNN(images) # Forward pass
            loss = loss_function(outputs, labels) # Calculate loss

            val_loss += loss.cpu().data*images.size(0) # Update validation loss

        val_loss = val_loss / val_size # Get the loss
        Val_loss_list.append(val_loss) # Append loss to list

        print(f'Epoch: {epoch}, Train Loss: {train_loss}, Train Accuracy: {train_accuracy}, Validation accuracy Accuracy: {val_accuracy}\n')

        # Check if validation loss has improved
        best_loss = float('inf') # initialize best_loss to infinity
        if val_loss < best_loss:
            best_loss = val_loss
            stop_early = 0
            # Save the best model
            torch.save(model.state_dict(), 'best_checkpoint.model')
        else:
            stop_early += 1
            if stop_early >= patience:
                print("Early stopping")
                break
            best_loss = val_loss
            stop_early = 0
            # Save the best model
            torch.save(model.state_dict(), 'best_checkpoint.model')

    return Train_loss_list, Val_loss_list

train_losses = list() # List to store the training losses of all folds
val_losses = list() # List to store the validation losses of all folds

for fold, (train_indices, val_indices) in enumerate(kfold.split(CLF_fullDataset)):

    print(f"\nFold {fold + 1}/{num_splits}\n") # Display the count of actual fold

    # Define the ratios for train, validation, and test datasets
    train_ratio = 0.7
    val_ratio = 0.20
    test_ratio = 0.10

    # Calculate the sizes of the train, validation, and test datasets
    train_size = int(train_ratio * len(CLF_fullDataset))
    val_size = int(val_ratio * len(CLF_fullDataset))
    test_size = len(CLF_fullDataset) - train_size - val_size

    # Split the full dataset into train, validation, and test datasets
    train_dataset, val_dataset, test_dataset = random_split(CLF_fullDataset, [train_size, val_size, test_size])

    # Create data loaders for the train and validation datasets
    CLF_train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
    CLF_val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
    CLF_test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

    # Create model
    modelCNN = ConvNet(num_classes = 2)

    # Pass model to GPU
    modelCNN.to(device)
    # Optimizer
    optimizer = torch.optim.Adam(modelCNN.parameters(), lr=0.001, weight_decay=0.0001)
    # Loss function
    loss_function = nn.CrossEntropyLoss()

    # K fold training loop
    tran_loss, val_loss = train(model = modelCNN, CLF_train_loader = CLF_train_loader, 
                                CLF_val_loader = CLF_val_loader, num_epoch = num_epoch,
                                loss_function = loss_function, optimizer = optimizer, 
                                device = device)

    train_losses.append(train_loss) # Append a list of train losses for the current fold
    val_losses.append(val_loss) # Append a list of validation losses for the current fold

    plt.rcParams['figure.figsize'] = [12, 7] # Set the size of the plot

    plt.plot(train_loss, label = f'Training loss. Fold: {fold + 1}')
    plt.plot(val_loss, label = f'Validation loss. Fold: {fold + 1}')
    plt.xlabel("n epoch")
    plt.legend(loc = 'upper right')
    plt.title(f'Training and Validation Loss Curves with K fold')
    plt.show
# Out:
# Fold 1/5
#
# ------------------------------------------------------------------------
#
# Epoch: 1/100
# Epoch: 0, Train Loss: 64.6427230834961, Train Accuracy: 0.5398230088495575, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 2/100
#
# Epoch: 1, Train Loss: 55.23296356201172, Train Accuracy: 0.504424778761062, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 3/100
#
# Epoch: 2, Train Loss: 23.635848999023438, Train Accuracy: 0.5929203539823009, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 4/100
#
# Epoch: 3, Train Loss: 28.55792999267578, Train Accuracy: 0.5575221238938053, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 5/100
#
# Epoch: 4, Train Loss: 20.7967586517334, Train Accuracy: 0.584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 6/100
#
# Epoch: 5, Train Loss: 16.071962356567383, Train Accuracy: 0.5575221238938053, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 7/100
#
# Epoch: 6, Train Loss: 14.936278343200684, Train Accuracy: 0.6637168141592921, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 8/100
#
# Epoch: 7, Train Loss: 25.43932342529297, Train Accuracy: 0.504424778761062, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 9/100
#
# Epoch: 8, Train Loss: 18.654388427734375, Train Accuracy: 0.6106194690265486, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 10/100
#
# Epoch: 9, Train Loss: 8.982386589050293, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 11/100
#
# Epoch: 10, Train Loss: 9.066472053527832, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 12/100
#
# Epoch: 11, Train Loss: 5.352168083190918, Train Accuracy: 0.672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 13/100
#
# Epoch: 12, Train Loss: 10.870842933654785, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 14/100
#
# Epoch: 13, Train Loss: 12.994447708129883, Train Accuracy: 0.584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 15/100
#
# Epoch: 14, Train Loss: 5.0657525062561035, Train Accuracy: 0.672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 16/100
#
# Epoch: 15, Train Loss: 2.414411783218384, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 17/100
#
# Epoch: 16, Train Loss: 6.675692081451416, Train Accuracy: 0.6991150442477876, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 18/100
#
# Epoch: 17, Train Loss: 3.564404010772705, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 19/100
#
# Epoch: 18, Train Loss: 3.734792947769165, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 20/100
#
# Epoch: 19, Train Loss: 2.9241814613342285, Train Accuracy: 0.7345132743362832, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 21/100
#
# Epoch: 20, Train Loss: 2.4559004306793213, Train Accuracy: 0.6814159292035398, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 22/100
#
# Epoch: 21, Train Loss: 0.8670647740364075, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 23/100
#
# Epoch: 22, Train Loss: 1.1059536933898926, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 24/100
#
# Epoch: 23, Train Loss: 0.870230495929718, Train Accuracy: 0.7256637168141593, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 25/100
#
# Epoch: 24, Train Loss: 1.0002684593200684, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 26/100
#
# Epoch: 25, Train Loss: 0.6365967988967896, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 27/100
#
# Epoch: 26, Train Loss: 0.9504556059837341, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 28/100
#
# Epoch: 27, Train Loss: 0.5399103164672852, Train Accuracy: 0.831858407079646, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 29/100
#
# Epoch: 28, Train Loss: 0.6488235592842102, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 30/100
#
# Epoch: 29, Train Loss: 0.6229970455169678, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 31/100
#
# Epoch: 30, Train Loss: 5.033560752868652, Train Accuracy: 0.7079646017699115, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 32/100
#
# Epoch: 31, Train Loss: 3.082869052886963, Train Accuracy: 0.7345132743362832, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 33/100
#
# Epoch: 32, Train Loss: 1.5510282516479492, Train Accuracy: 0.7256637168141593, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 34/100
#
# Epoch: 33, Train Loss: 0.7435933351516724, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 35/100
#
# Epoch: 34, Train Loss: 1.4528130292892456, Train Accuracy: 0.7433628318584071, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 36/100
#
# Epoch: 35, Train Loss: 0.8978119492530823, Train Accuracy: 0.7787610619469026, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 37/100
#
# Epoch: 36, Train Loss: 0.45845064520835876, Train Accuracy: 0.8849557522123894, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 38/100
#
# Epoch: 37, Train Loss: 0.36593174934387207, Train Accuracy: 0.8584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 39/100
#
# Epoch: 38, Train Loss: 0.25546368956565857, Train Accuracy: 0.9292035398230089, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 40/100
#
# Epoch: 39, Train Loss: 0.22449152171611786, Train Accuracy: 0.9203539823008849, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 41/100
#
# Epoch: 40, Train Loss: 0.37774428725242615, Train Accuracy: 0.8938053097345132, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 42/100
#
# Epoch: 41, Train Loss: 0.34801536798477173, Train Accuracy: 0.8938053097345132, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 43/100
#
# Epoch: 42, Train Loss: 0.16828668117523193, Train Accuracy: 0.9292035398230089, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 44/100
#
# Epoch: 43, Train Loss: 0.18224652111530304, Train Accuracy: 0.9292035398230089, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 45/100
#
# Epoch: 44, Train Loss: 0.26393231749534607, Train Accuracy: 0.9380530973451328, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 46/100
#
# Epoch: 45, Train Loss: 0.2581256628036499, Train Accuracy: 0.911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 47/100
#
# Epoch: 46, Train Loss: 0.14332324266433716, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 48/100
#
# Epoch: 47, Train Loss: 0.24831977486610413, Train Accuracy: 0.9469026548672567, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 49/100
#
# Epoch: 48, Train Loss: 0.2139921933412552, Train Accuracy: 0.9203539823008849, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 50/100
#
# Epoch: 49, Train Loss: 0.10075954347848892, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 51/100
#
# Epoch: 50, Train Loss: 0.24512453377246857, Train Accuracy: 0.9469026548672567, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 52/100
#
# Epoch: 51, Train Loss: 0.11877737939357758, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 53/100
#
# Epoch: 52, Train Loss: 0.12429677695035934, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 54/100
#
# Epoch: 53, Train Loss: 0.0992347002029419, Train Accuracy: 0.9557522123893806, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 55/100
#
# Epoch: 54, Train Loss: 0.21856269240379333, Train Accuracy: 0.9469026548672567, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 56/100
#
# Epoch: 55, Train Loss: 0.196954146027565, Train Accuracy: 0.9380530973451328, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 57/100
#
# Epoch: 56, Train Loss: 0.15835370123386383, Train Accuracy: 0.9469026548672567, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 58/100
#
# Epoch: 57, Train Loss: 0.11972193419933319, Train Accuracy: 0.9557522123893806, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 59/100
#
# Epoch: 58, Train Loss: 0.0770542174577713, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 60/100
#
# Epoch: 59, Train Loss: 0.17253312468528748, Train Accuracy: 0.9469026548672567, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 61/100
#
# Epoch: 60, Train Loss: 0.09629638493061066, Train Accuracy: 0.9557522123893806, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 62/100
#
# Epoch: 61, Train Loss: 0.05955575034022331, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 63/100
#
# Epoch: 62, Train Loss: 0.09763306379318237, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 64/100
#
# Epoch: 63, Train Loss: 0.10188215225934982, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 65/100
#
# Epoch: 64, Train Loss: 0.08830401301383972, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 66/100
#
# Epoch: 65, Train Loss: 0.07472167909145355, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 67/100
#
# Epoch: 66, Train Loss: 0.05808425322175026, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 68/100
#
# Epoch: 67, Train Loss: 0.02618284337222576, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 69/100
#
# Epoch: 68, Train Loss: 0.07766919583082199, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 70/100
#
# Epoch: 69, Train Loss: 0.01705450937151909, Train Accuracy: 1.0, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 71/100
#
# Epoch: 70, Train Loss: 0.052279382944107056, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 72/100
#
# Epoch: 71, Train Loss: 0.024045392870903015, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 73/100
#
# Epoch: 72, Train Loss: 0.07506705820560455, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 74/100
#
# Epoch: 73, Train Loss: 0.07441702485084534, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 75/100
#
# Epoch: 74, Train Loss: 0.04100711643695831, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 76/100
#
# Epoch: 75, Train Loss: 0.02637268789112568, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 77/100
#
# Epoch: 76, Train Loss: 0.010232474654912949, Train Accuracy: 1.0, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 78/100
#
# Epoch: 77, Train Loss: 0.04648987203836441, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 79/100
#
# Epoch: 78, Train Loss: 0.05725482478737831, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 80/100
#
# Epoch: 79, Train Loss: 0.037354111671447754, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 81/100
#
# Epoch: 80, Train Loss: 0.033994484692811966, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 82/100
#
# Epoch: 81, Train Loss: 0.029798749834299088, Train Accuracy: 1.0, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 83/100
#
# Epoch: 82, Train Loss: 0.0793139636516571, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 84/100
#
# Epoch: 83, Train Loss: 0.05581340566277504, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 85/100
#
# Epoch: 84, Train Loss: 0.03195785731077194, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 86/100
#
# Epoch: 85, Train Loss: 0.02281264029443264, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 87/100
#
# Epoch: 86, Train Loss: 0.0423949770629406, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 88/100
#
# Epoch: 87, Train Loss: 0.029975639656186104, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 89/100
#
# Epoch: 88, Train Loss: 0.022013241425156593, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 90/100
#
# Epoch: 89, Train Loss: 0.011347239837050438, Train Accuracy: 1.0, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 91/100
#
# Epoch: 90, Train Loss: 0.02289305068552494, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 92/100
#
# Epoch: 91, Train Loss: 0.021529383957386017, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 93/100
#
# Epoch: 92, Train Loss: 0.05819041654467583, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 94/100
#
# Epoch: 93, Train Loss: 0.015056660398840904, Train Accuracy: 1.0, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 95/100
#
# Epoch: 94, Train Loss: 0.05769876763224602, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 96/100
#
# Epoch: 95, Train Loss: 0.014772068709135056, Train Accuracy: 1.0, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 97/100
#
# Epoch: 96, Train Loss: 0.014393744058907032, Train Accuracy: 1.0, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 98/100
#
# Epoch: 97, Train Loss: 0.031062614172697067, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 99/100
#
# Epoch: 98, Train Loss: 0.00876374077051878, Train Accuracy: 1.0, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 100/100
#
# Epoch: 99, Train Loss: 0.069082111120224, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
#
# Fold 2/5
#
# ------------------------------------------------------------------------
#
# Epoch: 1/100
#
# Epoch: 0, Train Loss: 34.86785125732422, Train Accuracy: 0.5929203539823009, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 2/100
#
# Epoch: 1, Train Loss: 34.994468688964844, Train Accuracy: 0.5752212389380531, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 3/100
#
# Epoch: 2, Train Loss: 42.246116638183594, Train Accuracy: 0.5398230088495575, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 4/100
#
# Epoch: 3, Train Loss: 14.987527847290039, Train Accuracy: 0.6106194690265486, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 5/100
#
# Epoch: 4, Train Loss: 43.97897720336914, Train Accuracy: 0.504424778761062, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 6/100
#
# Epoch: 5, Train Loss: 26.467363357543945, Train Accuracy: 0.6017699115044248, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 7/100
#
# Epoch: 6, Train Loss: 14.911911964416504, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 8/100
#
# Epoch: 7, Train Loss: 25.902751922607422, Train Accuracy: 0.5575221238938053, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 9/100
#
# Epoch: 8, Train Loss: 9.450807571411133, Train Accuracy: 0.6371681415929203, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 10/100
#
# Epoch: 9, Train Loss: 14.274311065673828, Train Accuracy: 0.5663716814159292, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 11/100
#
# Epoch: 10, Train Loss: 20.61424446105957, Train Accuracy: 0.6194690265486725, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 12/100
#
# Epoch: 11, Train Loss: 17.828893661499023, Train Accuracy: 0.6017699115044248, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 13/100
#
# Epoch: 12, Train Loss: 38.40335464477539, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 14/100
#
# Epoch: 13, Train Loss: 29.881526947021484, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 15/100
#
# Epoch: 14, Train Loss: 14.954566955566406, Train Accuracy: 0.6460176991150443, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 16/100
#
# Epoch: 15, Train Loss: 28.81723403930664, Train Accuracy: 0.6814159292035398, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 17/100
#
# Epoch: 16, Train Loss: 13.632227897644043, Train Accuracy: 0.7079646017699115, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 18/100
#
# Epoch: 17, Train Loss: 19.911338806152344, Train Accuracy: 0.6814159292035398, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 19/100
#
# Epoch: 18, Train Loss: 13.376054763793945, Train Accuracy: 0.6814159292035398, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 20/100
#
# Epoch: 19, Train Loss: 4.786238670349121, Train Accuracy: 0.7433628318584071, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 21/100
#
# Epoch: 20, Train Loss: 4.8008012771606445, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 22/100
#
# Epoch: 21, Train Loss: 5.236035346984863, Train Accuracy: 0.7787610619469026, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 23/100
#
# Epoch: 22, Train Loss: 3.367475986480713, Train Accuracy: 0.8053097345132744, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 24/100
#
# Epoch: 23, Train Loss: 8.380693435668945, Train Accuracy: 0.7787610619469026, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 25/100
#
# Epoch: 24, Train Loss: 12.172517776489258, Train Accuracy: 0.6902654867256637, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 26/100
#
# Epoch: 25, Train Loss: 7.021955490112305, Train Accuracy: 0.7787610619469026, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 27/100
#
# Epoch: 26, Train Loss: 5.429481029510498, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 28/100
#
# Epoch: 27, Train Loss: 6.886340141296387, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 29/100
#
# Epoch: 28, Train Loss: 7.123474597930908, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 30/100
#
# Epoch: 29, Train Loss: 9.045965194702148, Train Accuracy: 0.584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 31/100
#
# Epoch: 30, Train Loss: 3.699460029602051, Train Accuracy: 0.7964601769911505, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 32/100
#
# Epoch: 31, Train Loss: 1.9668759107589722, Train Accuracy: 0.8053097345132744, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 33/100
#
# Epoch: 32, Train Loss: 4.706286907196045, Train Accuracy: 0.7079646017699115, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 34/100
#
# Epoch: 33, Train Loss: 5.8017377853393555, Train Accuracy: 0.7787610619469026, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 35/100
#
# Epoch: 34, Train Loss: 3.3362879753112793, Train Accuracy: 0.7876106194690266, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 36/100
#
# Epoch: 35, Train Loss: 3.248875141143799, Train Accuracy: 0.8584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 37/100
#
# Epoch: 36, Train Loss: 4.348776340484619, Train Accuracy: 0.7964601769911505, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 38/100
#
# Epoch: 37, Train Loss: 3.9791293144226074, Train Accuracy: 0.7345132743362832, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 39/100
#
# Epoch: 38, Train Loss: 1.9658223390579224, Train Accuracy: 0.831858407079646, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 40/100
#
# Epoch: 39, Train Loss: 2.8143393993377686, Train Accuracy: 0.7876106194690266, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 41/100
#
# Epoch: 40, Train Loss: 1.9566755294799805, Train Accuracy: 0.8761061946902655, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 42/100
#
# Epoch: 41, Train Loss: 14.373724937438965, Train Accuracy: 0.6902654867256637, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 43/100
#
# Epoch: 42, Train Loss: 8.73923397064209, Train Accuracy: 0.7345132743362832, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 44/100
#
# Epoch: 43, Train Loss: 2.9157795906066895, Train Accuracy: 0.8672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 45/100
#
# Epoch: 44, Train Loss: 3.874936103820801, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 46/100
#
# Epoch: 45, Train Loss: 3.123610258102417, Train Accuracy: 0.7964601769911505, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 47/100
#
# Epoch: 46, Train Loss: 6.2738356590271, Train Accuracy: 0.7699115044247787, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 48/100
#
# Epoch: 47, Train Loss: 4.0407280921936035, Train Accuracy: 0.8053097345132744, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 49/100
#
# Epoch: 48, Train Loss: 2.1530704498291016, Train Accuracy: 0.8761061946902655, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 50/100
#
# Epoch: 49, Train Loss: 12.852262496948242, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 51/100
#
# Epoch: 50, Train Loss: 4.06416130065918, Train Accuracy: 0.7876106194690266, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 52/100
#
# Epoch: 51, Train Loss: 1.8944728374481201, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 53/100
#
# Epoch: 52, Train Loss: 3.179248809814453, Train Accuracy: 0.8053097345132744, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 54/100
#
# Epoch: 53, Train Loss: 17.272066116333008, Train Accuracy: 0.7964601769911505, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 55/100
#
# Epoch: 54, Train Loss: 4.255833625793457, Train Accuracy: 0.7433628318584071, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 56/100
#
# Epoch: 55, Train Loss: 3.22121000289917, Train Accuracy: 0.7699115044247787, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 57/100
#
# Epoch: 56, Train Loss: 1.2159132957458496, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 58/100
#
# Epoch: 57, Train Loss: 1.538999319076538, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 59/100
#
# Epoch: 58, Train Loss: 2.6598289012908936, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 60/100
#
# Epoch: 59, Train Loss: 3.2820632457733154, Train Accuracy: 0.8584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 61/100
#
# Epoch: 60, Train Loss: 2.3905868530273438, Train Accuracy: 0.8761061946902655, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 62/100
#
# Epoch: 61, Train Loss: 1.7204806804656982, Train Accuracy: 0.8761061946902655, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 63/100
#
# Epoch: 62, Train Loss: 2.1703639030456543, Train Accuracy: 0.831858407079646, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 64/100
#
# Epoch: 63, Train Loss: 8.942551612854004, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 65/100
#
# Epoch: 64, Train Loss: 1.4028635025024414, Train Accuracy: 0.8849557522123894, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 66/100
#
# Epoch: 65, Train Loss: 1.2919542789459229, Train Accuracy: 0.9203539823008849, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 67/100
#
# Epoch: 66, Train Loss: 5.702803611755371, Train Accuracy: 0.7876106194690266, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 68/100
#
# Epoch: 67, Train Loss: 1.1271708011627197, Train Accuracy: 0.9026548672566371, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 69/100
#
# Epoch: 68, Train Loss: 1.3160241842269897, Train Accuracy: 0.8672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 70/100
#
# Epoch: 69, Train Loss: 1.0754764080047607, Train Accuracy: 0.8761061946902655, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 71/100
#
# Epoch: 70, Train Loss: 0.5029559135437012, Train Accuracy: 0.9380530973451328, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 72/100
#
# Epoch: 71, Train Loss: 1.3006476163864136, Train Accuracy: 0.9380530973451328, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 73/100
#
# Epoch: 72, Train Loss: 0.8171809315681458, Train Accuracy: 0.9292035398230089, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 74/100
#
# Epoch: 73, Train Loss: 2.6372852325439453, Train Accuracy: 0.8672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 75/100
#
# Epoch: 74, Train Loss: 1.4023685455322266, Train Accuracy: 0.8938053097345132, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 76/100
#
# Epoch: 75, Train Loss: 3.655467987060547, Train Accuracy: 0.7876106194690266, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 77/100
#
# Epoch: 76, Train Loss: 1.1220753192901611, Train Accuracy: 0.9292035398230089, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 78/100
#
# Epoch: 77, Train Loss: 0.6747269034385681, Train Accuracy: 0.911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 79/100
#
# Epoch: 78, Train Loss: 1.987019658088684, Train Accuracy: 0.8761061946902655, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 80/100
#
# Epoch: 79, Train Loss: 0.8938410878181458, Train Accuracy: 0.9203539823008849, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 81/100
#
# Epoch: 80, Train Loss: 0.31508997082710266, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 82/100
#
# Epoch: 81, Train Loss: 0.5595249533653259, Train Accuracy: 0.9734513274336283, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 83/100
#
# Epoch: 82, Train Loss: 0.5301539301872253, Train Accuracy: 0.9380530973451328, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 84/100
#
# Epoch: 83, Train Loss: 1.334855556488037, Train Accuracy: 0.9469026548672567, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 85/100
#
# Epoch: 84, Train Loss: 0.7556616067886353, Train Accuracy: 0.9292035398230089, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 86/100
#
# Epoch: 85, Train Loss: 0.4582647383213043, Train Accuracy: 0.9557522123893806, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 87/100
#
# Epoch: 86, Train Loss: 0.30947110056877136, Train Accuracy: 0.9557522123893806, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 88/100
#
# Epoch: 87, Train Loss: 0.19124256074428558, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 89/100
#
# Epoch: 88, Train Loss: 1.0314780473709106, Train Accuracy: 0.9380530973451328, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 90/100
#
# Epoch: 89, Train Loss: 0.3116951584815979, Train Accuracy: 0.9557522123893806, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 91/100
#
# Epoch: 90, Train Loss: 0.7231097221374512, Train Accuracy: 0.911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 92/100
#
# Epoch: 91, Train Loss: 0.19361864030361176, Train Accuracy: 0.9911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 93/100
#
# Epoch: 92, Train Loss: 1.1061570644378662, Train Accuracy: 0.9380530973451328, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 94/100
#
# Epoch: 93, Train Loss: 0.11069201678037643, Train Accuracy: 0.9823008849557522, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 95/100
#
# Epoch: 94, Train Loss: 0.5333187580108643, Train Accuracy: 0.9557522123893806, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 96/100
#
# Epoch: 95, Train Loss: 0.24070200324058533, Train Accuracy: 0.9469026548672567, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 97/100
#
# Epoch: 96, Train Loss: 0.5912801027297974, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 98/100
#
# Epoch: 97, Train Loss: 0.3229697346687317, Train Accuracy: 0.9557522123893806, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 99/100
#
# Epoch: 98, Train Loss: 0.28155073523521423, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 100/100
#
# Epoch: 99, Train Loss: 0.5720311999320984, Train Accuracy: 0.9646017699115044, Validation accuracy Accuracy: 0.0
#
#
# Fold 3/5
#
# ------------------------------------------------------------------------
#
# Epoch: 1/100
#
# Epoch: 0, Train Loss: 69.98168182373047, Train Accuracy: 0.49557522123893805, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 2/100
#
# Epoch: 1, Train Loss: 27.058408737182617, Train Accuracy: 0.46017699115044247, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 3/100
#
# Epoch: 2, Train Loss: 29.8227596282959, Train Accuracy: 0.46017699115044247, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 4/100
#
# Epoch: 3, Train Loss: 41.33928680419922, Train Accuracy: 0.5221238938053098, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 5/100
#
# Epoch: 4, Train Loss: 16.895444869995117, Train Accuracy: 0.584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 6/100
#
# Epoch: 5, Train Loss: 44.29925537109375, Train Accuracy: 0.4690265486725664, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 7/100
#
# Epoch: 6, Train Loss: 22.769622802734375, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 8/100
#
# Epoch: 7, Train Loss: 17.060768127441406, Train Accuracy: 0.5398230088495575, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 9/100
#
# Epoch: 8, Train Loss: 16.155521392822266, Train Accuracy: 0.5132743362831859, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 10/100
#
# Epoch: 9, Train Loss: 15.867596626281738, Train Accuracy: 0.5929203539823009, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 11/100
#
# Epoch: 10, Train Loss: 12.546712875366211, Train Accuracy: 0.584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 12/100
#
# Epoch: 11, Train Loss: 4.589025974273682, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 13/100
#
# Epoch: 12, Train Loss: 7.942160606384277, Train Accuracy: 0.5486725663716814, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 14/100
#
# Epoch: 13, Train Loss: 19.719633102416992, Train Accuracy: 0.5575221238938053, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 15/100
#
# Epoch: 14, Train Loss: 12.964226722717285, Train Accuracy: 0.5398230088495575, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 16/100
#
# Epoch: 15, Train Loss: 15.281977653503418, Train Accuracy: 0.6017699115044248, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 17/100
#
# Epoch: 16, Train Loss: 8.448974609375, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 18/100
#
# Epoch: 17, Train Loss: 8.000903129577637, Train Accuracy: 0.6991150442477876, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 19/100
#
# Epoch: 18, Train Loss: 4.710599899291992, Train Accuracy: 0.7345132743362832, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 20/100
#
# Epoch: 19, Train Loss: 2.844639301300049, Train Accuracy: 0.7699115044247787, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 21/100
#
# Epoch: 20, Train Loss: 2.5997674465179443, Train Accuracy: 0.7433628318584071, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 22/100
#
# Epoch: 21, Train Loss: 5.099827766418457, Train Accuracy: 0.672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 23/100
#
# Epoch: 22, Train Loss: 1.9965565204620361, Train Accuracy: 0.7876106194690266, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 24/100
#
# Epoch: 23, Train Loss: 2.8795342445373535, Train Accuracy: 0.7787610619469026, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 25/100
#
# Epoch: 24, Train Loss: 2.013608932495117, Train Accuracy: 0.7699115044247787, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 26/100
#
# Epoch: 25, Train Loss: 1.7538433074951172, Train Accuracy: 0.7787610619469026, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 27/100
#
# Epoch: 26, Train Loss: 3.66208815574646, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 28/100
#
# Epoch: 27, Train Loss: 7.083983421325684, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 29/100
#
# Epoch: 28, Train Loss: 4.139936923980713, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 30/100
#
# Epoch: 29, Train Loss: 1.9051822423934937, Train Accuracy: 0.8230088495575221, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 31/100
#
# Epoch: 30, Train Loss: 2.2452094554901123, Train Accuracy: 0.7345132743362832, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 32/100
#
# Epoch: 31, Train Loss: 2.2982540130615234, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 33/100
#
# Epoch: 32, Train Loss: 3.309823989868164, Train Accuracy: 0.6991150442477876, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 34/100
#
# Epoch: 33, Train Loss: 1.4155328273773193, Train Accuracy: 0.831858407079646, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 35/100
#
# Epoch: 34, Train Loss: 1.6029359102249146, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 36/100
#
# Epoch: 35, Train Loss: 2.054555654525757, Train Accuracy: 0.7964601769911505, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 37/100
#
# Epoch: 36, Train Loss: 12.022875785827637, Train Accuracy: 0.5929203539823009, Validation accuracy Accuracy: 0.0
#
# ...
#
# ------------------------------------------------------------------------
#
# Epoch: 6/100
#
# Epoch: 5, Train Loss: 8.37553596496582, Train Accuracy: 0.5309734513274337, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 7/100
#
# Epoch: 6, Train Loss: 34.43187713623047, Train Accuracy: 0.5398230088495575, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 8/100
#
# Epoch: 7, Train Loss: 31.58480453491211, Train Accuracy: 0.4690265486725664, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 9/100
#
# Epoch: 8, Train Loss: 11.376469612121582, Train Accuracy: 0.5929203539823009, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 10/100
#
# Epoch: 9, Train Loss: 7.427990436553955, Train Accuracy: 0.6017699115044248, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 11/100
#
# Epoch: 10, Train Loss: 4.780994415283203, Train Accuracy: 0.672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 12/100
#
# Epoch: 11, Train Loss: 12.10090160369873, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 13/100
#
# Epoch: 12, Train Loss: 16.28215789794922, Train Accuracy: 0.5221238938053098, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 14/100
#
# Epoch: 13, Train Loss: 19.013561248779297, Train Accuracy: 0.5132743362831859, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 15/100
#
# Epoch: 14, Train Loss: 12.612850189208984, Train Accuracy: 0.5752212389380531, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 16/100
#
# Epoch: 15, Train Loss: 5.29929780960083, Train Accuracy: 0.6991150442477876, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 17/100
#
# Epoch: 16, Train Loss: 4.521236896514893, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 18/100
#
# Epoch: 17, Train Loss: 4.204137802124023, Train Accuracy: 0.6371681415929203, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 19/100
#
# Epoch: 18, Train Loss: 5.5550217628479, Train Accuracy: 0.6371681415929203, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 20/100
#
# Epoch: 19, Train Loss: 5.404794216156006, Train Accuracy: 0.584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 21/100
#
# Epoch: 20, Train Loss: 3.6331448554992676, Train Accuracy: 0.7345132743362832, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 22/100
#
# Epoch: 21, Train Loss: 4.011762619018555, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 23/100
#
# Epoch: 22, Train Loss: 3.921536684036255, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 24/100
#
# Epoch: 23, Train Loss: 1.7549731731414795, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 25/100
#
# Epoch: 24, Train Loss: 1.5849871635437012, Train Accuracy: 0.6991150442477876, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 26/100
#
# Epoch: 25, Train Loss: 10.423473358154297, Train Accuracy: 0.584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 27/100
#
# Epoch: 26, Train Loss: 5.13682746887207, Train Accuracy: 0.672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 28/100
#
# Epoch: 27, Train Loss: 2.332926034927368, Train Accuracy: 0.672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 29/100
#
# Epoch: 28, Train Loss: 2.5285704135894775, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 30/100
#
# Epoch: 29, Train Loss: 0.7960458993911743, Train Accuracy: 0.8230088495575221, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 31/100
#
# Epoch: 30, Train Loss: 7.39202356338501, Train Accuracy: 0.672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 32/100
#
# Epoch: 31, Train Loss: 4.943432331085205, Train Accuracy: 0.7079646017699115, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 33/100
#
# Epoch: 32, Train Loss: 6.2138495445251465, Train Accuracy: 0.6283185840707964, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 34/100
#
# Epoch: 33, Train Loss: 4.949005603790283, Train Accuracy: 0.6902654867256637, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 35/100
#
# Epoch: 34, Train Loss: 3.2974441051483154, Train Accuracy: 0.7433628318584071, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 36/100
#
# Epoch: 35, Train Loss: 2.8329386711120605, Train Accuracy: 0.7168141592920354, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 37/100
#
# Epoch: 36, Train Loss: 1.0196613073349, Train Accuracy: 0.831858407079646, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 38/100
#
# Epoch: 37, Train Loss: 0.8321647047996521, Train Accuracy: 0.7699115044247787, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 39/100
#
# Epoch: 38, Train Loss: 0.36478957533836365, Train Accuracy: 0.8672566371681416, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 40/100
#
# Epoch: 39, Train Loss: 0.19982311129570007, Train Accuracy: 0.9292035398230089, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 41/100
#
# Epoch: 40, Train Loss: 2.326969623565674, Train Accuracy: 0.7787610619469026, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 42/100
#
# Epoch: 41, Train Loss: 1.7454420328140259, Train Accuracy: 0.7699115044247787, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 43/100
#
# Epoch: 42, Train Loss: 0.5944939851760864, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 44/100
#
# Epoch: 43, Train Loss: 0.3263230323791504, Train Accuracy: 0.8584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 45/100
#
# Epoch: 44, Train Loss: 0.3867277503013611, Train Accuracy: 0.8938053097345132, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 46/100
#
# Epoch: 45, Train Loss: 0.39921835064888, Train Accuracy: 0.8584070796460177, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 47/100
#
# Epoch: 46, Train Loss: 0.305317223072052, Train Accuracy: 0.8938053097345132, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 48/100
#
# Epoch: 47, Train Loss: 0.39408135414123535, Train Accuracy: 0.911504424778761, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 49/100
#
# Epoch: 48, Train Loss: 0.3637921214103699, Train Accuracy: 0.8849557522123894, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 50/100
#
# Epoch: 49, Train Loss: 0.8554620742797852, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 51/100
#
# Epoch: 50, Train Loss: 1.0796023607254028, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 52/100
#
# Epoch: 51, Train Loss: 1.2537819147109985, Train Accuracy: 0.7433628318584071, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 53/100
#
# Epoch: 52, Train Loss: 0.8702260851860046, Train Accuracy: 0.8053097345132744, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 54/100
#
# Epoch: 53, Train Loss: 1.978691577911377, Train Accuracy: 0.7256637168141593, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 55/100
#
# Epoch: 54, Train Loss: 5.724480152130127, Train Accuracy: 0.6017699115044248, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 56/100
#
# Epoch: 55, Train Loss: 4.259795665740967, Train Accuracy: 0.6548672566371682, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 57/100
#
# Epoch: 56, Train Loss: 1.968740701675415, Train Accuracy: 0.6017699115044248, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 58/100
#
# Epoch: 57, Train Loss: 1.417015552520752, Train Accuracy: 0.5663716814159292, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 59/100
#
# Epoch: 58, Train Loss: 6.7796478271484375, Train Accuracy: 0.5752212389380531, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 60/100
#
# Epoch: 59, Train Loss: 1.6273245811462402, Train Accuracy: 0.7610619469026548, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 61/100
#
# Epoch: 60, Train Loss: 0.5815200805664062, Train Accuracy: 0.8495575221238938, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 62/100
#
# Epoch: 61, Train Loss: 1.0447181463241577, Train Accuracy: 0.7522123893805309, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 63/100
#
# Epoch: 62, Train Loss: 0.5264675617218018, Train Accuracy: 0.8495575221238938, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 64/100
#
# Epoch: 63, Train Loss: 0.37085145711898804, Train Accuracy: 0.8407079646017699, Validation accuracy Accuracy: 0.0
#
# ------------------------------------------------------------------------
#
# Epoch: 65/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-699a76a37f58> in <module>
#     141                                 CLF_val_loader = CLF_val_loader, num_epoch = num_epoch,
#     142                                 loss_function = loss_function, optimizer = optimizer,
# --> 143                                 device = device)
#     144
#     145     train_losses.append(train_loss) # Append a list of train losses for the current fold
#
# <ipython-input-14-699a76a37f58> in train(model, CLF_train_loader, CLF_val_loader, num_epoch, loss_function, optimizer, device)
#      66
#      67         # Iterate over the validation dataset
# ---> 68         for i, (images, labels) in enumerate(CLF_val_loader):
#      69
#      70             # Pass images and labels to GPU
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataset.py in __getitem__(self, idx)
#     293         if isinstance(idx, list):
#     294             return self.dataset[[self.indices[i] for i in idx]]
# --> 295         return self.dataset[self.indices[idx]]
#     296
#     297     def __len__(self):
#
# <ipython-input-4-c738232a4204> in __getitem__(self, idx)
#      80             # Apply any specified transforms to the image
#      81             if self.transform:
# ---> 82                 image = self.transform(image)
#      83             else:
#      84                 image = transforms.ToTensor(image)
#
# ~/anaconda3/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# ~/anaconda3/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     133             Tensor: Converted image.
#     134         """
# --> 135         return F.to_tensor(pic)
#     136
#     137     def __repr__(self) -> str:
#
# ~/anaconda3/lib/python3.7/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#     167     img = img.view(pic.size[1], pic.size[0], len(pic.getbands()))
#     168     # put it from HWC to CHW format
# --> 169     img = img.permute((2, 0, 1)).contiguous()
#     170     if isinstance(img, torch.ByteTensor):
#     171         return img.to(dtype=default_float_dtype).div(255)
#
# KeyboardInterrupt:

# %% [markdown]
# **Test the model for patches**

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

def test(model, CLF_test_loader, loss_function):
    model.eval()  # Set the model to evaluation mode

    test_loss = 0.0
    test_accuracy = 0.0
    true_labels = []
    pred_labels = []

    with torch.no_grad():  # Disabling gradient calculation
        for images, labels in CLF_test_loader:
            if torch.cuda.is_available():
                images = images.cuda()
                labels = labels.cuda()

            outputs = model(images)
            loss = loss_function(outputs, labels)
            test_loss += loss.item() * images.size(0)
            _, prediction = torch.max(outputs, 1)

            true_labels.extend(labels.cpu().numpy())
            pred_labels.extend(prediction.cpu().numpy())

            test_accuracy += torch.sum(prediction == labels.data).item()

    test_loss /= len(CLF_test_loader.dataset)
    test_accuracy /= len(CLF_test_loader.dataset)

    # Calculate the confusion matrix
    conf_matrix = confusion_matrix(true_labels, pred_labels)

    # Output the classification report for the test set
    print("Test Classification Report:")
    print(classification_report(true_labels, pred_labels))

    # Display the confusion matrix using matplotlib
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(conf_matrix.shape[0]):
        for j in range(conf_matrix.shape[1]):
            ax.text(x=j, y=i, s=conf_matrix[i, j], va='center', ha='center')

    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('Actual Label')
    plt.tight_layout()
    plt.show()

    return test_loss, test_accuracy, true_labels, pred_labels, conf_matrix

# Usage:
test_loss, test_accuracy, true_labels, pred_labels, conf_matrix = test(modelCNN, CLF_test_loader, loss_function)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
# Out:
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.90      0.82      0.86        11
#
#     accuracy                           0.82        17
#    macro avg       0.81      0.83      0.81        17
# weighted avg       0.83      0.82      0.83        17
# Test Loss: 3.540614969590131, Test Accuracy: 0.8235294117647058

# %% [markdown]
# # **Patient evalulation**

# %% [markdown]
# *Notes for evaluation:*
#
# - *0: **Not infected***
# - *1: **Infected***

# %% [markdown]
# **Retrieve all the patients from the test set in order to define the most optimal threshold**

# %%
# Initialize the dictionary to store the data
data_dict = {'INFECTED': {}, 'NOT_INFECTED': {}}

# Read the file line by line
with open('/fhome/gia01/vl_project2/autoencoder/txt files/train_thresholds.txt', 'r') as file:
    for line in file:
        # Strip any whitespace and split the line by comma
        parts = line.strip().split(',')
        # Assign the parts to variables for clarity
        sample_id, path, status = parts[0], parts[1], int(parts[2])
        # Depending on the status, add the entry to the respective dictionary key
        if status == 1:
            data_dict['INFECTED'][sample_id] = path
        else:
            data_dict['NOT_INFECTED'][sample_id] = path

# Now data_dict is populated with the data in the format you wanted.
print(data_dict)
# Out:
# {'INFECTED': {'B22-65': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-65_1/', 'B22-222': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-222_1/', 'B22-130': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-130_1/', 'B22-225': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-225_1/', 'B22-263': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-263_1/', 'B22-39': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-39_1/', 'B22-169': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-169_1/', 'B22-75': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-75_1/', 'B22-49': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-49_1/', 'B22-82': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-82_1/', 'B22-159': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-159_1/', 'B22-96': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-96_1/', 'B22-255': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-255_1/', 'B22-310': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-310_1/', 'B22-105': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-105_1/', 'B22-281': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-281_1/', 'B22-81': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-81_1/', 'B22-309': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-309_1/', 'B22-44': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-44_1/', 'B22-273': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-273_1/'}, 'NOT_INFECTED': {'B22-110': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-110_1/', 'B22-143': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-143_1/', 'B22-239': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-239_1/', 'B22-220': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-220_1/', 'B22-196': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-196_1/', 'B22-202': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-202_1/', 'B22-283': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-283_1/', 'B22-173': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-173_1/', 'B22-107': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-107_1/', 'B22-207': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-207_1/', 'B22-199': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-199_1/', 'B22-233': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-233_1/', 'B22-269': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-269_1/', 'B22-148': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-148_1/', 'B22-91': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-91_1/', 'B22-282': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-282_1/', 'B22-168': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-168_1/', 'B22-227': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-227_1/', 'B22-111': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-111_1/', 'B22-189': '/fhome/mapsiv/QuironHelico/CroppedPatches/B22-189_1/'}}

# %% [markdown]
# Load checkpoint model

# %%
checkpoint = torch.load("best_checkpoint1.model") # Load checkpoint

model = ConvNet(num_classes = 2) # Load model
model.load_state_dict(checkpoint) # Load checkpoint into the model
model.eval() # Set model to evaluation mode
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (fc): Linear(in_features=802816, out_features=2, bias=True)
# )

# %% [markdown]
# Data structure in order to store predictions at inference time

# %%
# Empty list in which the predictions of the model will be saved
CNN_predictions = list()

# %%
# Define data augmentation transforms
myTransforms = transforms.Compose([ transforms.Resize((224,224)), # Resize the image to 224x224
                                    transforms.ToTensor(),       # Convert the image to a tensor
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # Normalize the image
])

# %% [markdown]
# **Prediction function**

# %%
# Define prediction function
def prediction(img_path, myTransforms):

    """
    This function return the prediction for a particular patch.
    
    - Output:

    -- 0: Not infected
    -- 1: Infected
    """

    image = Image.open(img_path) # Open image with PIL
    # Convert the image to RGB if it's not already
    if image.mode != 'RGB':
        image = image.convert('RGB')
    image_tensor = myTransforms(image).float() # Feed image to the the transformations in order to convert it to tensor
    image_tensor = image_tensor.unsqueeze_(0) # Adds a dimension of size one at index 0. _ indicates that it will be in place
    """ By adding a batch dimension the image can be passed through the network which expect inputs to have four dimensions"""

    # Check if cuda is available - pass tensor image
    if torch.cuda.is_available():
        image_tensor.cuda()

    # Input fo the model
    input1 = Variable(image_tensor)

    # Output of the model
    output = model(input1) # Returns an array with probabilities for each class
    index = output.data.numpy().argmax() # Apply arg max to get the category id with maximum probability

    return index

# %%
# Declaration of the function in order to make the conversion
def calculate_confidence(percentage, threshold):
    """
    Calculate the confidence level based on a given percentage using a rule of three.

    Parameters:
    percentage (float): A percentage value where 0.1 maps to a confidence level of 1.

    Returns:
    float: The calculated confidence level, capped at 1 for percentages over 0.1.
    """
    # If the percentage is greater than 0.1, the confidence is 1
    if percentage >= threshold:
        return 1
    else:
        # Otherwise, scale the confidence linearly from 0 to 1 as the percentage goes from 0 to 0.1
        # Using the rule of three: percentage / 0.1 = confidence / 1
        confidence = percentage / threshold
        return confidence

# %%
def process_patient(image_path):
    # Get the prediction for the patch
    pred = prediction(image_path, myTransforms)
    return pred

# %%
y_scores001 = list() # Store the probability estimates of being from the infected class, threshold: %1
y_scores002 = list() # Store the probability estimates of being from the infected class, threshold: %2
y_scores0025 = list() # Store the probability estimates of being from the infected class, threshold: %2.5
y_scores003 = list() # Store the probability estimates of being from the infected class, threshold: %3
y_scores0035 = list() # Store the probability estimates of being from the infected class, threshold: %3.5
y_scores004 = list() # Store the probability estimates of being from the infected class, threshold: %4
y_scores005 = list() # Store the probability estimates of being from the infected class, threshold: %5
y_scores007 = list() # Store the probability estimates of being from the infected class, threshold: %7
y_scores015 = list() # Store the probability estimates of being from the infected class, threshold: %15
y_scores050 = list() # Store the probability estimates of being from the infected class, threshold: %50
y_scores075 = list() # Store the probability estimates of being from the infected class, threshold: %75
y_scores090 = list() # Store the probability estimates of being from the infected class, threshold: %90

infectedPer_list = list() # Store the infected percentage for each patient

y_test = list() # Store the ground truth from the data, infected or not infected

i = 0 # Counter

# Iterate over the test set
for label in data_dict:

    patients_dict = data_dict[label] # Get the dictionary of the patients

    # Determine ground truth
    if (label == "INFECTED"): # Infected
        gt = 1
    
    else: # Not infected
        gt = 0

    # Iterate over the patients
    for patient in patients_dict:

        patient_predictions = list() # Initialize the data structure in which the prediction for a particular patient will be stored
        # Get a list of all the full paths for the images from the patient
        images_files_full_paths = [os.path.join(patients_dict[patient], file) for file in os.listdir(patients_dict[patient])]

        """
        if __name__ == '__main__':

            with Pool() as p:
                # Use the map function to distribute the work among the worker processes
                patient_predictions = p.map(process_patient, images_files_full_paths)
        """
        
        # Iterate over all the images of the patient
        for image_path in images_files_full_paths:

            pred = prediction(image_path, myTransforms) # Get the prediction for the patch
            patient_predictions.append(pred) # Append the prediction

        value = 1 # Infected class

        # Calculate the percentage of infected detected patches for a particular patient
        infected_percentage = patient_predictions.count(value) / len(patient_predictions)

        infectedPer_list.append(infected_percentage)

        # Calculate the estimated probability of the model based on predefined criterion for the diagnosis
        # += threshold of infected patches in a patient - estimated probability of infection: 100%
        # 0% of infected patches in a patient - estimated probability of infection: 0%
        y_score001 = calculate_confidence(infected_percentage, 0.01) # Threshold: %1
        y_score002 = calculate_confidence(infected_percentage, 0.02) # Threshold: %2
        y_score0025 = calculate_confidence(infected_percentage, 0.025) # Threshold: %2.5
        y_score003 = calculate_confidence(infected_percentage, 0.03) # Threshold: %3
        y_score0035 = calculate_confidence(infected_percentage, 0.035) # Threshold: %3.5
        y_score004 = calculate_confidence(infected_percentage, 0.04) # Threshold: %4
        y_score005 = calculate_confidence(infected_percentage, 0.05) # Threshold: %5
        y_score007 = calculate_confidence(infected_percentage, 0.07) # Threshold: %7
        y_score015 = calculate_confidence(infected_percentage, 0.15) # Threshold: %15
        y_score050 = calculate_confidence(infected_percentage, 0.50) # Threshold: %50
        y_score075 = calculate_confidence(infected_percentage, 0.75) # Threshold: %75
        y_score090 = calculate_confidence(infected_percentage, 0.90) # Threshold: %90
        
        # Update y_score and y_test lists
        y_scores001.append(y_score001)
        y_scores002.append(y_score002)
        y_scores0025.append(y_score0025)
        y_scores003.append(y_score003)
        y_scores0035.append(y_score0035)
        y_scores004.append(y_score004)
        y_scores005.append(y_score005)
        y_scores007.append(y_score007)
        y_scores015.append(y_score015)
        y_scores050.append(y_score050)
        y_scores075.append(y_score075)
        y_scores090.append(y_score090)

        y_test.append(gt) # Ground truth

        i += 1
        print("Patient", str(i) + ":", "for 0.01  |", gt, "-", round(y_score001, 3))
        print("Patient", str(i) + ":", "for 0.02  |", gt, "-", round(y_score002, 3))
        print("Patient", str(i) + ":", "for 0.025 |", gt, "-", round(y_score0025, 3))
        print("Patient", str(i) + ":", "for 0.03  |", gt, "-", round(y_score003, 3))
        print("Patient", str(i) + ":", "for 0.035 |", gt, "-", round(y_score0035, 3))
        print("Patient", str(i) + ":", "for 0.04  |", gt, "-", round(y_score004, 3))
        print("Patient", str(i) + ":", "for 0.05  |", gt, "-", round(y_score005, 3))
        print("Patient", str(i) + ":", "for 0.07  |", gt, "-", round(y_score007, 3))
        print("Patient", str(i) + ":", "for 0.15  |", gt, "-", round(y_score015, 3))
        print("Patient", str(i) + ":", "for 0.50  |", gt, "-", round(y_score050, 3))
        print("Patient", str(i) + ":", "for 0.75  |", gt, "-", round(y_score075, 3))
        print("Patient", str(i) + ":", "for 0.90  |", gt, "-", round(y_score090, 3))
        print()

        # print(y_scores) # Display scores
        # print(y_test) # Display ground truth

        # Update control data structure
        # CNN_predictions.append((str(patient), [gt, y_score]))
# Out:
# Patient 1: for 0.01  | 1 - 1
# Patient 1: for 0.02  | 1 - 1
# Patient 1: for 0.025 | 1 - 1
# Patient 1: for 0.03  | 1 - 1
# Patient 1: for 0.035 | 1 - 1
# Patient 1: for 0.04  | 1 - 1
# Patient 1: for 0.05  | 1 - 1
# Patient 1: for 0.07  | 1 - 1
# Patient 1: for 0.15  | 1 - 0.588
# Patient 1: for 0.50  | 1 - 0.176
# Patient 1: for 0.75  | 1 - 0.118
# Patient 1: for 0.90  | 1 - 0.098
#
# Patient 2: for 0.01  | 1 - 1
# Patient 2: for 0.02  | 1 - 1
# Patient 2: for 0.025 | 1 - 1
# Patient 2: for 0.03  | 1 - 1
# Patient 2: for 0.035 | 1 - 1
# Patient 2: for 0.04  | 1 - 1
# Patient 2: for 0.05  | 1 - 1
# Patient 2: for 0.07  | 1 - 1
# Patient 2: for 0.15  | 1 - 1
# Patient 2: for 0.50  | 1 - 0.365
# Patient 2: for 0.75  | 1 - 0.243
# Patient 2: for 0.90  | 1 - 0.203
#
# Patient 3: for 0.01  | 1 - 1
# Patient 3: for 0.02  | 1 - 1
# Patient 3: for 0.025 | 1 - 1
# Patient 3: for 0.03  | 1 - 1
# Patient 3: for 0.035 | 1 - 1
# Patient 3: for 0.04  | 1 - 1
# Patient 3: for 0.05  | 1 - 1
# Patient 3: for 0.07  | 1 - 1
# Patient 3: for 0.15  | 1 - 0.478
# Patient 3: for 0.50  | 1 - 0.143
# Patient 3: for 0.75  | 1 - 0.096
# Patient 3: for 0.90  | 1 - 0.08
#
# Patient 4: for 0.01  | 1 - 1
# Patient 4: for 0.02  | 1 - 1
# Patient 4: for 0.025 | 1 - 1
# Patient 4: for 0.03  | 1 - 1
# Patient 4: for 0.035 | 1 - 1
# Patient 4: for 0.04  | 1 - 1
# Patient 4: for 0.05  | 1 - 1
# Patient 4: for 0.07  | 1 - 1
# Patient 4: for 0.15  | 1 - 0.816
# Patient 4: for 0.50  | 1 - 0.245
# Patient 4: for 0.75  | 1 - 0.163
# Patient 4: for 0.90  | 1 - 0.136
#
# Patient 5: for 0.01  | 1 - 1
# Patient 5: for 0.02  | 1 - 1
# Patient 5: for 0.025 | 1 - 1
# Patient 5: for 0.03  | 1 - 1
# Patient 5: for 0.035 | 1 - 1
# Patient 5: for 0.04  | 1 - 1
# Patient 5: for 0.05  | 1 - 1
# Patient 5: for 0.07  | 1 - 1
# Patient 5: for 0.15  | 1 - 1
# Patient 5: for 0.50  | 1 - 0.381
# Patient 5: for 0.75  | 1 - 0.254
# Patient 5: for 0.90  | 1 - 0.212
#
# Patient 6: for 0.01  | 1 - 1
# Patient 6: for 0.02  | 1 - 1
# Patient 6: for 0.025 | 1 - 1
# Patient 6: for 0.03  | 1 - 1
# Patient 6: for 0.035 | 1 - 1
# Patient 6: for 0.04  | 1 - 1
# Patient 6: for 0.05  | 1 - 1
# Patient 6: for 0.07  | 1 - 1
# Patient 6: for 0.15  | 1 - 0.49
# Patient 6: for 0.50  | 1 - 0.147
# Patient 6: for 0.75  | 1 - 0.098
# Patient 6: for 0.90  | 1 - 0.082
#
# Patient 7: for 0.01  | 1 - 1
# Patient 7: for 0.02  | 1 - 1
# Patient 7: for 0.025 | 1 - 1
# Patient 7: for 0.03  | 1 - 1
# Patient 7: for 0.035 | 1 - 1
# Patient 7: for 0.04  | 1 - 1
# Patient 7: for 0.05  | 1 - 1
# Patient 7: for 0.07  | 1 - 1
# Patient 7: for 0.15  | 1 - 1
# Patient 7: for 0.50  | 1 - 0.397
# Patient 7: for 0.75  | 1 - 0.265
# Patient 7: for 0.90  | 1 - 0.221
#
# Patient 8: for 0.01  | 1 - 1
# Patient 8: for 0.02  | 1 - 1
# Patient 8: for 0.025 | 1 - 1
# Patient 8: for 0.03  | 1 - 1
# Patient 8: for 0.035 | 1 - 1
# Patient 8: for 0.04  | 1 - 1
# Patient 8: for 0.05  | 1 - 1
# Patient 8: for 0.07  | 1 - 1
# Patient 8: for 0.15  | 1 - 1
# Patient 8: for 0.50  | 1 - 0.434
# Patient 8: for 0.75  | 1 - 0.289
# Patient 8: for 0.90  | 1 - 0.241
#
# Patient 9: for 0.01  | 1 - 1
# Patient 9: for 0.02  | 1 - 1
# Patient 9: for 0.025 | 1 - 1
# Patient 9: for 0.03  | 1 - 1
# Patient 9: for 0.035 | 1 - 1
# Patient 9: for 0.04  | 1 - 1
# Patient 9: for 0.05  | 1 - 0.92
# Patient 9: for 0.07  | 1 - 0.657
# Patient 9: for 0.15  | 1 - 0.307
# Patient 9: for 0.50  | 1 - 0.092
# Patient 9: for 0.75  | 1 - 0.061
# Patient 9: for 0.90  | 1 - 0.051
#
# Patient 10: for 0.01  | 1 - 1
# Patient 10: for 0.02  | 1 - 1
# Patient 10: for 0.025 | 1 - 1
# Patient 10: for 0.03  | 1 - 1
# Patient 10: for 0.035 | 1 - 0.878
# Patient 10: for 0.04  | 1 - 0.768
# Patient 10: for 0.05  | 1 - 0.614
# Patient 10: for 0.07  | 1 - 0.439
# Patient 10: for 0.15  | 1 - 0.205
# Patient 10: for 0.50  | 1 - 0.061
# Patient 10: for 0.75  | 1 - 0.041
# Patient 10: for 0.90  | 1 - 0.034
#
# Patient 11: for 0.01  | 1 - 1
# Patient 11: for 0.02  | 1 - 1
# Patient 11: for 0.025 | 1 - 1
# Patient 11: for 0.03  | 1 - 1
# Patient 11: for 0.035 | 1 - 1
# Patient 11: for 0.04  | 1 - 1
# Patient 11: for 0.05  | 1 - 1
# Patient 11: for 0.07  | 1 - 1
# Patient 11: for 0.15  | 1 - 0.749
# Patient 11: for 0.50  | 1 - 0.225
# Patient 11: for 0.75  | 1 - 0.15
# Patient 11: for 0.90  | 1 - 0.125
#
# Patient 12: for 0.01  | 1 - 1
# Patient 12: for 0.02  | 1 - 1
# Patient 12: for 0.025 | 1 - 1
# Patient 12: for 0.03  | 1 - 1
# Patient 12: for 0.035 | 1 - 1
# Patient 12: for 0.04  | 1 - 1
# Patient 12: for 0.05  | 1 - 0.982
# Patient 12: for 0.07  | 1 - 0.702
# Patient 12: for 0.15  | 1 - 0.327
# Patient 12: for 0.50  | 1 - 0.098
# Patient 12: for 0.75  | 1 - 0.065
# Patient 12: for 0.90  | 1 - 0.055
#
# Patient 13: for 0.01  | 1 - 1
# Patient 13: for 0.02  | 1 - 1
# Patient 13: for 0.025 | 1 - 1
# Patient 13: for 0.03  | 1 - 1
# Patient 13: for 0.035 | 1 - 1
# Patient 13: for 0.04  | 1 - 1
# Patient 13: for 0.05  | 1 - 1
# Patient 13: for 0.07  | 1 - 1
# Patient 13: for 0.15  | 1 - 1
# Patient 13: for 0.50  | 1 - 0.51
# Patient 13: for 0.75  | 1 - 0.34
# Patient 13: for 0.90  | 1 - 0.283
#
# Patient 14: for 0.01  | 1 - 1
# Patient 14: for 0.02  | 1 - 1
# Patient 14: for 0.025 | 1 - 0.907
# Patient 14: for 0.03  | 1 - 0.756
# Patient 14: for 0.035 | 1 - 0.648
# Patient 14: for 0.04  | 1 - 0.567
# Patient 14: for 0.05  | 1 - 0.454
# Patient 14: for 0.07  | 1 - 0.324
# Patient 14: for 0.15  | 1 - 0.151
# Patient 14: for 0.50  | 1 - 0.045
# Patient 14: for 0.75  | 1 - 0.03
# Patient 14: for 0.90  | 1 - 0.025
#
# Patient 15: for 0.01  | 1 - 1
# Patient 15: for 0.02  | 1 - 1
# Patient 15: for 0.025 | 1 - 1
# Patient 15: for 0.03  | 1 - 1
# Patient 15: for 0.035 | 1 - 1
# Patient 15: for 0.04  | 1 - 1
# Patient 15: for 0.05  | 1 - 1
# Patient 15: for 0.07  | 1 - 0.742
# Patient 15: for 0.15  | 1 - 0.346
# Patient 15: for 0.50  | 1 - 0.104
# Patient 15: for 0.75  | 1 - 0.069
# Patient 15: for 0.90  | 1 - 0.058
#
# Patient 16: for 0.01  | 1 - 1
# Patient 16: for 0.02  | 1 - 1
# Patient 16: for 0.025 | 1 - 1
# Patient 16: for 0.03  | 1 - 1
# Patient 16: for 0.035 | 1 - 1
# Patient 16: for 0.04  | 1 - 1
# Patient 16: for 0.05  | 1 - 1
# Patient 16: for 0.07  | 1 - 1
# Patient 16: for 0.15  | 1 - 1
# Patient 16: for 0.50  | 1 - 0.481
# Patient 16: for 0.75  | 1 - 0.321
# Patient 16: for 0.90  | 1 - 0.267
#
# Patient 17: for 0.01  | 1 - 1
# Patient 17: for 0.02  | 1 - 0.562
# Patient 17: for 0.025 | 1 - 0.449
# Patient 17: for 0.03  | 1 - 0.375
# Patient 17: for 0.035 | 1 - 0.321
# Patient 17: for 0.04  | 1 - 0.281
# Patient 17: for 0.05  | 1 - 0.225
# Patient 17: for 0.07  | 1 - 0.161
# Patient 17: for 0.15  | 1 - 0.075
# Patient 17: for 0.50  | 1 - 0.022
# Patient 17: for 0.75  | 1 - 0.015
# Patient 17: for 0.90  | 1 - 0.012
#
# Patient 18: for 0.01  | 1 - 1
# Patient 18: for 0.02  | 1 - 1
# Patient 18: for 0.025 | 1 - 1
# Patient 18: for 0.03  | 1 - 1
# Patient 18: for 0.035 | 1 - 1
# Patient 18: for 0.04  | 1 - 1
# Patient 18: for 0.05  | 1 - 1
# Patient 18: for 0.07  | 1 - 1
# Patient 18: for 0.15  | 1 - 0.485
# Patient 18: for 0.50  | 1 - 0.146
# Patient 18: for 0.75  | 1 - 0.097
# Patient 18: for 0.90  | 1 - 0.081
#
# Patient 19: for 0.01  | 1 - 1
# Patient 19: for 0.02  | 1 - 0.975
# Patient 19: for 0.025 | 1 - 0.78
# Patient 19: for 0.03  | 1 - 0.65
# Patient 19: for 0.035 | 1 - 0.557
# Patient 19: for 0.04  | 1 - 0.487
# Patient 19: for 0.05  | 1 - 0.39
# Patient 19: for 0.07  | 1 - 0.279
# Patient 19: for 0.15  | 1 - 0.13
# Patient 19: for 0.50  | 1 - 0.039
# Patient 19: for 0.75  | 1 - 0.026
# Patient 19: for 0.90  | 1 - 0.022
#
# Patient 20: for 0.01  | 1 - 1
# Patient 20: for 0.02  | 1 - 1
# Patient 20: for 0.025 | 1 - 1
# Patient 20: for 0.03  | 1 - 1
# Patient 20: for 0.035 | 1 - 1
# Patient 20: for 0.04  | 1 - 1
# Patient 20: for 0.05  | 1 - 1
# Patient 20: for 0.07  | 1 - 1
# Patient 20: for 0.15  | 1 - 1
# Patient 20: for 0.50  | 1 - 0.424
# Patient 20: for 0.75  | 1 - 0.283
# Patient 20: for 0.90  | 1 - 0.236
#
# Patient 21: for 0.01  | 0 - 0.2
# Patient 21: for 0.02  | 0 - 0.1
# Patient 21: for 0.025 | 0 - 0.08
# Patient 21: for 0.03  | 0 - 0.067
# Patient 21: for 0.035 | 0 - 0.057
# Patient 21: for 0.04  | 0 - 0.05
# Patient 21: for 0.05  | 0 - 0.04
# Patient 21: for 0.07  | 0 - 0.029
# Patient 21: for 0.15  | 0 - 0.013
# Patient 21: for 0.50  | 0 - 0.004
# Patient 21: for 0.75  | 0 - 0.003
# Patient 21: for 0.90  | 0 - 0.002
#
# Patient 22: for 0.01  | 0 - 0.245
# Patient 22: for 0.02  | 0 - 0.123
# Patient 22: for 0.025 | 0 - 0.098
# Patient 22: for 0.03  | 0 - 0.082
# Patient 22: for 0.035 | 0 - 0.07
# Patient 22: for 0.04  | 0 - 0.061
# Patient 22: for 0.05  | 0 - 0.049
# Patient 22: for 0.07  | 0 - 0.035
# Patient 22: for 0.15  | 0 - 0.016
# Patient 22: for 0.50  | 0 - 0.005
# Patient 22: for 0.75  | 0 - 0.003
# Patient 22: for 0.90  | 0 - 0.003
#
# Patient 23: for 0.01  | 0 - 0.466
# Patient 23: for 0.02  | 0 - 0.233
# Patient 23: for 0.025 | 0 - 0.186
# Patient 23: for 0.03  | 0 - 0.155
# Patient 23: for 0.035 | 0 - 0.133
# Patient 23: for 0.04  | 0 - 0.117
# Patient 23: for 0.05  | 0 - 0.093
# Patient 23: for 0.07  | 0 - 0.067
# Patient 23: for 0.15  | 0 - 0.031
# Patient 23: for 0.50  | 0 - 0.009
# Patient 23: for 0.75  | 0 - 0.006
# Patient 23: for 0.90  | 0 - 0.005
#
# Patient 24: for 0.01  | 0 - 0.034
# Patient 24: for 0.02  | 0 - 0.017
# Patient 24: for 0.025 | 0 - 0.014
# Patient 24: for 0.03  | 0 - 0.011
# Patient 24: for 0.035 | 0 - 0.01
# Patient 24: for 0.04  | 0 - 0.009
# Patient 24: for 0.05  | 0 - 0.007
# Patient 24: for 0.07  | 0 - 0.005
# Patient 24: for 0.15  | 0 - 0.002
# Patient 24: for 0.50  | 0 - 0.001
# Patient 24: for 0.75  | 0 - 0.0
# Patient 24: for 0.90  | 0 - 0.0
#
# Patient 25: for 0.01  | 0 - 0.293
# Patient 25: for 0.02  | 0 - 0.147
# Patient 25: for 0.025 | 0 - 0.117
# Patient 25: for 0.03  | 0 - 0.098
# Patient 25: for 0.035 | 0 - 0.084
# Patient 25: for 0.04  | 0 - 0.073
# Patient 25: for 0.05  | 0 - 0.059
# Patient 25: for 0.07  | 0 - 0.042
# Patient 25: for 0.15  | 0 - 0.02
# Patient 25: for 0.50  | 0 - 0.006
# Patient 25: for 0.75  | 0 - 0.004
# Patient 25: for 0.90  | 0 - 0.003
#
# Patient 26: for 0.01  | 0 - 0.412
# Patient 26: for 0.02  | 0 - 0.206
# Patient 26: for 0.025 | 0 - 0.165
# Patient 26: for 0.03  | 0 - 0.137
# Patient 26: for 0.035 | 0 - 0.118
# Patient 26: for 0.04  | 0 - 0.103
# Patient 26: for 0.05  | 0 - 0.082
# Patient 26: for 0.07  | 0 - 0.059
# Patient 26: for 0.15  | 0 - 0.027
# Patient 26: for 0.50  | 0 - 0.008
# Patient 26: for 0.75  | 0 - 0.005
# Patient 26: for 0.90  | 0 - 0.005
#
# Patient 27: for 0.01  | 0 - 0.122
# Patient 27: for 0.02  | 0 - 0.061
# Patient 27: for 0.025 | 0 - 0.049
# Patient 27: for 0.03  | 0 - 0.041
# Patient 27: for 0.035 | 0 - 0.035
# Patient 27: for 0.04  | 0 - 0.031
# Patient 27: for 0.05  | 0 - 0.024
# Patient 27: for 0.07  | 0 - 0.017
# Patient 27: for 0.15  | 0 - 0.008
# Patient 27: for 0.50  | 0 - 0.002
# Patient 27: for 0.75  | 0 - 0.002
# Patient 27: for 0.90  | 0 - 0.001
#
# Patient 28: for 0.01  | 0 - 0.397
# Patient 28: for 0.02  | 0 - 0.199
# Patient 28: for 0.025 | 0 - 0.159
# Patient 28: for 0.03  | 0 - 0.132
# Patient 28: for 0.035 | 0 - 0.113
# Patient 28: for 0.04  | 0 - 0.099
# Patient 28: for 0.05  | 0 - 0.079
# Patient 28: for 0.07  | 0 - 0.057
# Patient 28: for 0.15  | 0 - 0.026
# Patient 28: for 0.50  | 0 - 0.008
# Patient 28: for 0.75  | 0 - 0.005
# Patient 28: for 0.90  | 0 - 0.004
#
# Patient 29: for 0.01  | 0 - 0.178
# Patient 29: for 0.02  | 0 - 0.089
# Patient 29: for 0.025 | 0 - 0.071
# Patient 29: for 0.03  | 0 - 0.059
# Patient 29: for 0.035 | 0 - 0.051
# Patient 29: for 0.04  | 0 - 0.044
# Patient 29: for 0.05  | 0 - 0.036
# Patient 29: for 0.07  | 0 - 0.025
# Patient 29: for 0.15  | 0 - 0.012
# Patient 29: for 0.50  | 0 - 0.004
# Patient 29: for 0.75  | 0 - 0.002
# Patient 29: for 0.90  | 0 - 0.002
#
# Patient 30: for 0.01  | 0 - 0.719
# Patient 30: for 0.02  | 0 - 0.36
# Patient 30: for 0.025 | 0 - 0.288
# Patient 30: for 0.03  | 0 - 0.24
# Patient 30: for 0.035 | 0 - 0.206
# Patient 30: for 0.04  | 0 - 0.18
# Patient 30: for 0.05  | 0 - 0.144
# Patient 30: for 0.07  | 0 - 0.103
# Patient 30: for 0.15  | 0 - 0.048
# Patient 30: for 0.50  | 0 - 0.014
# Patient 30: for 0.75  | 0 - 0.01
# Patient 30: for 0.90  | 0 - 0.008
#
# Patient 31: for 0.01  | 0 - 0.563
# Patient 31: for 0.02  | 0 - 0.282
# Patient 31: for 0.025 | 0 - 0.225
# Patient 31: for 0.03  | 0 - 0.188
# Patient 31: for 0.035 | 0 - 0.161
# Patient 31: for 0.04  | 0 - 0.141
# Patient 31: for 0.05  | 0 - 0.113
# Patient 31: for 0.07  | 0 - 0.08
# Patient 31: for 0.15  | 0 - 0.038
# Patient 31: for 0.50  | 0 - 0.011
# Patient 31: for 0.75  | 0 - 0.008
# Patient 31: for 0.90  | 0 - 0.006
#
# Patient 32: for 0.01  | 0 - 0.304
# Patient 32: for 0.02  | 0 - 0.152
# Patient 32: for 0.025 | 0 - 0.122
# Patient 32: for 0.03  | 0 - 0.101
# Patient 32: for 0.035 | 0 - 0.087
# Patient 32: for 0.04  | 0 - 0.076
# Patient 32: for 0.05  | 0 - 0.061
# Patient 32: for 0.07  | 0 - 0.043
# Patient 32: for 0.15  | 0 - 0.02
# Patient 32: for 0.50  | 0 - 0.006
# Patient 32: for 0.75  | 0 - 0.004
# Patient 32: for 0.90  | 0 - 0.003
#
# Patient 33: for 0.01  | 0 - 0.306
# Patient 33: for 0.02  | 0 - 0.153
# Patient 33: for 0.025 | 0 - 0.122
# Patient 33: for 0.03  | 0 - 0.102
# Patient 33: for 0.035 | 0 - 0.087
# Patient 33: for 0.04  | 0 - 0.076
# Patient 33: for 0.05  | 0 - 0.061
# Patient 33: for 0.07  | 0 - 0.044
# Patient 33: for 0.15  | 0 - 0.02
# Patient 33: for 0.50  | 0 - 0.006
# Patient 33: for 0.75  | 0 - 0.004
# Patient 33: for 0.90  | 0 - 0.003
#
# Patient 34: for 0.01  | 0 - 1
# Patient 34: for 0.02  | 0 - 0.537
# Patient 34: for 0.025 | 0 - 0.43
# Patient 34: for 0.03  | 0 - 0.358
# Patient 34: for 0.035 | 0 - 0.307
# Patient 34: for 0.04  | 0 - 0.269
# Patient 34: for 0.05  | 0 - 0.215
# Patient 34: for 0.07  | 0 - 0.153
# Patient 34: for 0.15  | 0 - 0.072
# Patient 34: for 0.50  | 0 - 0.021
# Patient 34: for 0.75  | 0 - 0.014
# Patient 34: for 0.90  | 0 - 0.012
#
# Patient 35: for 0.01  | 0 - 0.0
# Patient 35: for 0.02  | 0 - 0.0
# Patient 35: for 0.025 | 0 - 0.0
# Patient 35: for 0.03  | 0 - 0.0
# Patient 35: for 0.035 | 0 - 0.0
# Patient 35: for 0.04  | 0 - 0.0
# Patient 35: for 0.05  | 0 - 0.0
# Patient 35: for 0.07  | 0 - 0.0
# Patient 35: for 0.15  | 0 - 0.0
# Patient 35: for 0.50  | 0 - 0.0
# Patient 35: for 0.75  | 0 - 0.0
# Patient 35: for 0.90  | 0 - 0.0
#
# Patient 36: for 0.01  | 0 - 0.166
# Patient 36: for 0.02  | 0 - 0.083
# Patient 36: for 0.025 | 0 - 0.066
# Patient 36: for 0.03  | 0 - 0.055
# Patient 36: for 0.035 | 0 - 0.047
# Patient 36: for 0.04  | 0 - 0.041
# Patient 36: for 0.05  | 0 - 0.033
# Patient 36: for 0.07  | 0 - 0.024
# Patient 36: for 0.15  | 0 - 0.011
# Patient 36: for 0.50  | 0 - 0.003
# Patient 36: for 0.75  | 0 - 0.002
# Patient 36: for 0.90  | 0 - 0.002
#
# Patient 37: for 0.01  | 0 - 0.976
# Patient 37: for 0.02  | 0 - 0.488
# Patient 37: for 0.025 | 0 - 0.39
# Patient 37: for 0.03  | 0 - 0.325
# Patient 37: for 0.035 | 0 - 0.279
# Patient 37: for 0.04  | 0 - 0.244
# Patient 37: for 0.05  | 0 - 0.195
# Patient 37: for 0.07  | 0 - 0.139
# Patient 37: for 0.15  | 0 - 0.065
# Patient 37: for 0.50  | 0 - 0.02
# Patient 37: for 0.75  | 0 - 0.013
# Patient 37: for 0.90  | 0 - 0.011
#
# Patient 38: for 0.01  | 0 - 0.209
# Patient 38: for 0.02  | 0 - 0.105
# Patient 38: for 0.025 | 0 - 0.084
# Patient 38: for 0.03  | 0 - 0.07
# Patient 38: for 0.035 | 0 - 0.06
# Patient 38: for 0.04  | 0 - 0.052
# Patient 38: for 0.05  | 0 - 0.042
# Patient 38: for 0.07  | 0 - 0.03
# Patient 38: for 0.15  | 0 - 0.014
# Patient 38: for 0.50  | 0 - 0.004
# Patient 38: for 0.75  | 0 - 0.003
# Patient 38: for 0.90  | 0 - 0.002
#
# Patient 39: for 0.01  | 0 - 1
# Patient 39: for 0.02  | 0 - 0.989
# Patient 39: for 0.025 | 0 - 0.791
# Patient 39: for 0.03  | 0 - 0.659
# Patient 39: for 0.035 | 0 - 0.565
# Patient 39: for 0.04  | 0 - 0.494
# Patient 39: for 0.05  | 0 - 0.395
# Patient 39: for 0.07  | 0 - 0.282
# Patient 39: for 0.15  | 0 - 0.132
# Patient 39: for 0.50  | 0 - 0.04
# Patient 39: for 0.75  | 0 - 0.026
# Patient 39: for 0.90  | 0 - 0.022
#
# Patient 40: for 0.01  | 0 - 0.664
# Patient 40: for 0.02  | 0 - 0.332
# Patient 40: for 0.025 | 0 - 0.266
# Patient 40: for 0.03  | 0 - 0.221
# Patient 40: for 0.035 | 0 - 0.19
# Patient 40: for 0.04  | 0 - 0.166
# Patient 40: for 0.05  | 0 - 0.133
# Patient 40: for 0.07  | 0 - 0.095
# Patient 40: for 0.15  | 0 - 0.044
# Patient 40: for 0.50  | 0 - 0.013
# Patient 40: for 0.75  | 0 - 0.009
# Patient 40: for 0.90  | 0 - 0.007

# %% [markdown]
# Based on the confidence interval for each threshold assign the binary classification
#
# *< 0.5: 0 - Not infected*
#
# *>= 0.5: 1 - Infected*

# %%
binary_labels001 = [1 if prob >= 0.5 else 0 for prob in y_scores001] # Threshold: %1
binary_labels002 = [1 if prob >= 0.5 else 0 for prob in y_scores002] # Threshold: %2
binary_labels0025 = [1 if prob >= 0.5 else 0 for prob in y_scores0025] # Threshold: %2.5
binary_labels003 = [1 if prob >= 0.5 else 0 for prob in y_scores003] # Threshold: %3
binary_labels0035 = [1 if prob >= 0.5 else 0 for prob in y_scores0035] # Threshold: %3.5
binary_labels004 = [1 if prob >= 0.5 else 0 for prob in y_scores004] # Threshold: %4
binary_labels005 = [1 if prob >= 0.5 else 0 for prob in y_scores005] # Threshold: %5
binary_labels007 = [1 if prob >= 0.5 else 0 for prob in y_scores007] # Threshold: %7
binary_labels015 = [1 if prob >= 0.5 else 0 for prob in y_scores015] # Threshold: %15
binary_labels050 = [1 if prob >= 0.5 else 0 for prob in y_scores050] # Threshold: %50
binary_labels075 = [1 if prob >= 0.5 else 0 for prob in y_scores075] # Threshold: %75
binary_labels090 = [1 if prob >= 0.5 else 0 for prob in y_scores090] # Threshold: %90

# %% [markdown]
# Plot confusion matrix for each threshold

# %%
# Assuming you have binary_labels0025, binary_labels0035, binary_labels004, binary_labels005, etc. already defined
# Define the thresholds for each binary label
thresholds = ['%1', '%2', '%2.5', '%3', '%3.5', '%4', '%5', '%7', '%15', '%50', '%75', '%90']
# Store all the binary labels in a list
binary_labels_list = [binary_labels001, binary_labels002, binary_labels0025, binary_labels003, binary_labels0035, binary_labels004, binary_labels005, binary_labels007, binary_labels015, binary_labels050, binary_labels075, binary_labels090]
# In order to store the true negative, false positive, false negative and true positive
ravels = list()

# Set the number of subplots based on the number of thresholds
n_cols = 3
n_rows = int(np.ceil(len(thresholds) / n_cols))

# Create a figure to hold all the subplots
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(n_cols * 4, n_rows * 4))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Loop through the thresholds and plot each confusion matrix
for i, threshold in enumerate(thresholds):
    # Compute confusion matrix
    cm = confusion_matrix(y_test, binary_labels_list[i])
    # Unpack the confusion matrix into true negative, false positive, false negative and true positive
    true_neg, false_pos, false_neg, true_pos = cm.ravel()
    # Store the ravel in a list
    ravel = [true_neg, false_pos, false_neg, true_pos]
    ravels.append(ravel)
    
    # Initialize the display object
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["0", "1"])

    # Plot in the next subplot
    disp.plot(ax=axes[i], cmap='Blues', colorbar=False)
    axes[i].set_title(f'Confusion matrix (Threshold: {threshold})')

# Hide any unused subplots
for ax in axes[len(thresholds):]:
    ax.axis('off')

# Adjust layout to prevent overlap
plt.tight_layout()

# Add more space between the plots
plt.subplots_adjust(wspace=0.4, hspace=0.6)

# Show the plot
plt.show()

# %% [markdown]
# Display for the ROC plot
#
# ***Receiver Operating Characteristic**: Graphical plot that illustrates the diagnostic ability of a binary classifier system as its discrimination threshold is varied*

# %%
# Lists to hold all TPRs and FPRs
TPRs = []
FPRs = []
AUCs = []

# Iterate over each threshold and corresponding confusion matrix ravel to calculate TPR and FPR
for i, threshold in enumerate(thresholds):
    true_neg, false_pos, false_neg, true_pos = ravels[i]

    # Calculate TPR and FPR
    TPR = true_pos / (true_pos + false_neg) if (true_pos + false_neg) != 0 else 0
    FPR = false_pos / (false_pos + true_neg) if (false_pos + true_neg) != 0 else 0

    TPRs.append(TPR)
    FPRs.append(FPR)

    # Calculate AUC for ROC curve
    AUC = auc([0, FPR, 1], [0, TPR, 1])
    AUCs.append(AUC)

    print(f"The accuracy of the model with a threshold of {threshold} is {(true_pos + true_neg) / (true_pos + true_neg + false_pos + false_neg):.2f}")
    print(f"The area under the ROC curve (AUC) for threshold {threshold} is {AUC:.2f}")
    print()

# Plot the ROC curve
plt.figure(figsize=(10, 8))
plt.plot(FPRs, TPRs, marker='o', linestyle='-', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # Random chance line

# Annotate each point on the ROC curve with its threshold
for i, threshold in enumerate(thresholds):
    plt.annotate(threshold, (FPRs[i], TPRs[i]), textcoords="offset points", xytext=(10,-5))

plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.show()
# Out:
# The accuracy of the model with a threshold of %1 is 0.85
# The area under the ROC curve (AUC) for threshold %1 is 0.85
#
# The accuracy of the model with a threshold of %2 is 0.95
# The area under the ROC curve (AUC) for threshold %2 is 0.95
#
# The accuracy of the model with a threshold of %2.5 is 0.95
# The area under the ROC curve (AUC) for threshold %2.5 is 0.95
#
# The accuracy of the model with a threshold of %3 is 0.95
# The area under the ROC curve (AUC) for threshold %3 is 0.95
#
# The accuracy of the model with a threshold of %3.5 is 0.95
# The area under the ROC curve (AUC) for threshold %3.5 is 0.95
#
# The accuracy of the model with a threshold of %4 is 0.95
# The area under the ROC curve (AUC) for threshold %4 is 0.95
#
# The accuracy of the model with a threshold of %5 is 0.93
# The area under the ROC curve (AUC) for threshold %5 is 0.93
#
# The accuracy of the model with a threshold of %7 is 0.90
# The area under the ROC curve (AUC) for threshold %7 is 0.90
#
# The accuracy of the model with a threshold of %15 is 0.75
# The area under the ROC curve (AUC) for threshold %15 is 0.75
#
# The accuracy of the model with a threshold of %50 is 0.53
# The area under the ROC curve (AUC) for threshold %50 is 0.53
#
# The accuracy of the model with a threshold of %75 is 0.50
# The area under the ROC curve (AUC) for threshold %75 is 0.50
#
# The accuracy of the model with a threshold of %90 is 0.50
# The area under the ROC curve (AUC) for threshold %90 is 0.50
